# %%
import pandas as pd
import json
import requests

# настройки Elasticsearch
url = "https://127.0.0.1:9200/_bulk"
auth = ("admin", "SamplePassword1!")
headers = {"Content-Type": "application/json"}

# загрузка CSV
df = pd.read_csv("assessments.csv")

# если нужно, минимальная очистка
df = df.fillna("")  # например, пустые строки вместо NaN

# функция для отправки данных в Elasticsearch
def send_bulk(df, index_name="assessments"):
    bulk_data = ""
    for _, row in df.iterrows():
        # каждая запись начинается с команды index
        bulk_data += json.dumps({"index": {"_index": index_name}}) + "\n"
        bulk_data += json.dumps(row.to_dict(), ensure_ascii=False) + "\n"

    # отправка в ES
    response = requests.post(url, headers=headers, data=bulk_data.encode("utf-8"), auth=auth, verify=False)
    print(response.status_code)
    print(response.text)

# отправка
send_bulk(df)

# %% [markdown]
# для маленьких таблиц

# %%
import pandas as pd
import json
import requests
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# настройки OpenSearch
url = "https://127.0.0.1:9200/_bulk"
auth = ("admin", "SamplePassword1!")
headers = {"Content-Type": "application/json"}


def load_csv_to_opensearch(csv_file, index_name):
    
    # загрузка CSV
    df = pd.read_csv(csv_file)

    # минимальная очистка
    df = df.fillna("")

    bulk_data = ""

    for _, row in df.iterrows():
        bulk_data += json.dumps({"index": {"_index": index_name}}) + "\n"
        bulk_data += json.dumps(row.to_dict(), ensure_ascii=False) + "\n"

    response = requests.post(
        url,
        headers=headers,
        data=bulk_data.encode("utf-8"),
        auth=auth,
        verify=False
    )

    print(f"{csv_file} → {index_name}")
    print(response.status_code)
    print(response.text)


# загрузка всех файлов
load_csv_to_opensearch("assessments.csv", "assessments")
load_csv_to_opensearch("courses.csv", "courses")
load_csv_to_opensearch("vle.csv", "vle")
# Out:
# vle.csv → vle
# 200
# {"took":211,"errors":false,"items":[{"index":{"_index":"vle","_id":"webjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"wubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":1,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"w-bjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":2,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"xObjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":3,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"xebjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":4,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"xubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":5,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"x-bjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":6,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"yObjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":7,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"yebjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":8,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"yubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":9,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"y-bjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":10,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"zObjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":11,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"zebjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":12,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"zubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":13,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"z-bjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":14,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"0ObjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":15,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"0ebjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":16,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"0ubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":17,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"0-bjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":18,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"1ObjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":19,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"1ebjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":20,"_primary_term":1,"status":201}},{"index":{"_index":"vle","_id":"1ubjLp0ByDq1tYEpf7M4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":21,"_primary_term":1,"status":201}},{"index":{"_in ...

# %%
#load_csv_to_opensearch("studentAssessment.csv", "student_assessment")
# load_csv_to_opensearch("studentInfo.csv", "student_info")
# load_csv_to_opensearch("studentRegistration.csv", "student_registration")
# load_csv_to_opensearch("studentVle.csv", "student_vle")

# %% [markdown]
# для больших файлов

# %%
import pandas as pd
import json
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

url = "https://127.0.0.1:9200/_bulk"
auth = ("admin", "SamplePassword1!")
headers = {"Content-Type": "application/json"}


def load_csv_to_opensearch(csv_file, index_name, batch_size=1000):

    print(f"Loading {csv_file} → {index_name}")

    df = pd.read_csv(csv_file)
    df = df.fillna("")

    total = len(df)
    print("Total rows:", total)

    for start in range(0, total, batch_size):

        end = start + batch_size
        batch = df.iloc[start:end]

        bulk_data = ""

        for _, row in batch.iterrows():
            bulk_data += json.dumps({"index": {"_index": index_name}}) + "\n"
            bulk_data += json.dumps(row.to_dict(), ensure_ascii=False) + "\n"

        response = requests.post(
            url,
            headers=headers,
            data=bulk_data.encode("utf-8"),
            auth=auth,
            verify=False
        )

        print(f"Loaded {end if end < total else total}/{total} | status {response.status_code}")


# загрузка файлов

#load_csv_to_opensearch("studentAssessment.csv", "student_assessment")

#load_csv_to_opensearch("studentInfo.csv", "student_info")

#load_csv_to_opensearch("studentRegistration.csv", "student_registration")

load_csv_to_opensearch("studentVle.csv", "student_vle")
# Out:
# Loading studentVle.csv → student_vle
# Total rows: 10655280
# Loaded 1000/10655280 | status 200
# Loaded 2000/10655280 | status 200
# Loaded 3000/10655280 | status 200
# Loaded 4000/10655280 | status 200
# Loaded 5000/10655280 | status 200
# Loaded 6000/10655280 | status 200
# Loaded 7000/10655280 | status 200
# Loaded 8000/10655280 | status 200
# Loaded 9000/10655280 | status 200
# Loaded 10000/10655280 | status 200
# Loaded 11000/10655280 | status 200
# Loaded 12000/10655280 | status 200
# Loaded 13000/10655280 | status 200
# Loaded 14000/10655280 | status 200
# Loaded 15000/10655280 | status 200
# Loaded 16000/10655280 | status 200
# Loaded 17000/10655280 | status 200
# Loaded 18000/10655280 | status 200
# Loaded 19000/10655280 | status 200
# Loaded 20000/10655280 | status 200
# Loaded 21000/10655280 | status 200
# Loaded 22000/10655280 | status 200
# Loaded 23000/10655280 | status 200
# Loaded 24000/10655280 | status 200
# Loaded 25000/10655280 | status 200
# Loaded 26000/10655280 | status 200
# Loaded 27000/10655280 | status 200
# Loaded 28000/10655280 | status 200
# Loaded 29000/10655280 | status 200
# Loaded 30000/10655280 | status 200
# Loaded 31000/10655280 | status 200
# Loaded 32000/10655280 | status 200
# Loaded 33000/10655280 | status 200
# Loaded 34000/10655280 | status 200
# Loaded 35000/10655280 | status 200
# Loaded 36000/10655280 | status 200
# Loaded 37000/10655280 | status 200
# Loaded 38000/10655280 | status 200
# Loaded 39000/10655280 | status 200
# Loaded 40000/10655280 | status 200
# Loaded 41000/10655280 | status 200
# Loaded 42000/10655280 | status 200
# Loaded 43000/10655280 | status 200
# Loaded 44000/10655280 | status 200
# Loaded 45000/10655280 | status 200
# Loaded 46000/10655280 | status 200
# Loaded 47000/10655280 | status 200
# Loaded 48000/10655280 | status 200
# Loaded 49000/10655280 | status 200
# Loaded 50000/10655280 | status 200
# Loaded 51000/10655280 | status 200
# Loaded 52000/10655280 | status 200
# Loaded 53000/10655280 | status 200
# Loaded 54000/10655280 | status 200
# Loaded 55000/10655280 | status 200
# Loaded 56000/10655280 | status 200
# Loaded 57000/10655280 | status 200
# Loaded 58000/10655280 | status 200
# Loaded 59000/10655280 | status 200
# Loaded 60000/10655280 | status 200
# Loaded 61000/10655280 | status 200
# Loaded 62000/10655280 | status 200
# Loaded 63000/10655280 | status 200
# Loaded 64000/10655280 | status 200
# Loaded 65000/10655280 | status 200
# Loaded 66000/10655280 | status 200
# Loaded 67000/10655280 | status 200
# Loaded 68000/10655280 | status 200
# Loaded 69000/10655280 | status 200
# Loaded 70000/10655280 | status 200
# Loaded 71000/10655280 | status 200
# Loaded 72000/10655280 | status 200
# Loaded 73000/10655280 | status 200
# Loaded 74000/10655280 | status 200
# Loaded 75000/10655280 | status 200
# Loaded 76000/10655280 | status 200
# Loaded 77000/10655280 | status 200
# Loaded 78000/10655280 | status 200
# Loaded 79000/10655280 | status 200
# Loaded 80000/10655280 | status 200
# Loaded 81000/10655280 | status 200
# Loaded 82000/10655280 | status 200
# Loaded 83000/10655280 | status 200
# Loaded 84000/10655280 | status 200
# Loaded 85000/10655280 | status 200
# Loaded 86000/10655280 | status 200
# Loaded 87000/10655280 | status 200
# Loaded 88000/10655280 | status 200
# Loaded 89000/10655280 | status 200
# Loaded 90000/10655280 | status 200
# Loaded 91000/10655280 | status 200
# Loaded 92000/10655280 | status 200
# Loaded 93000/10655280 | status 200
# Loaded 94000/10655280 | status 200
# Loaded 95000/10655280 | status 200
# Loaded 96000/10655280 | status 200
# Loaded 97000/10655280 | status 200
# Loaded 98000/10655280 | status 200
# Loaded 99000/10655280 | status 200
# Loaded 100000/10655280 | status 200
# Loaded 101000/10655280 | status 200
# Loaded 102000/10655280 | status 200
# Loaded 103000/10655280 | status 200
# Loaded 104000/10655280 | status 200
# Loaded 105000/10655280 | status 200
# Loaded 106000/10655280 | status 200
# Loaded 107000/10655280 | status 200
# Loaded 108000/10655280 | status 200
# Loaded 109000/10655280 | status 200
# Loaded 110000/10655280 | status 200
# Loaded 111000/10655280 | status 200
# Loaded 112000/10655280 | status 200
# Loaded 113000/10655280 | status 200
# Loaded 114000/10655280 | status 200
# Loaded 115000/10655280 | status 200
# Loaded 116000/10655280 | status 200
# Loaded 117000/10655280 | status 200
# Loaded 118000/10655280 | status 200
# Loaded 119000/10655280 | status 200
# Loaded 120000/10655280 | status 200
# Loaded 121000/10655280 | status 200
# Loaded 122000/10655280 | status 200
# Loaded 123000/10655280 | status 200
# Loaded 124000/10655280 | status 200
# Loaded 125000/10655280 | status 200
# Loaded 126000/10655280 | status 200
# Loaded 127000/10655280 | status 200
# Loaded 128000/10655280 | status 200
# Loaded 129000/10655280 | status 200
# Loaded 130000/10655280 | status 200
# Loaded 131000/10655280 | status 200
# Loaded 132000/10655280 | status 200
# Loaded 133000/10655280 | status 200
# Loaded 134000/10655280 | status 200
# Loaded 135000/10655280 | status 200
# Loaded 136000/10655280 | status 200
# Loaded 137000/10655280 | status 200
# Loaded 138000/10655280 | status 200
# Loaded 139000/10655280 | status 200
# Loaded 140000/10655280 | status 200
# Loaded 141000/10655280 | status 200
# Loaded 142000/10655280 | status 200
# Loaded 143000/10655280 | status 200
# Loaded 144000/10655280 | status 200
# Loaded 145000/10655280 | status 200
# Loaded 146000/10655280 | status 200
# Loaded 147000/10655280 | status 200
# Loaded 148000/10655280 | status 200
# Loaded 149000/10655280 | status 200
# Loaded 150000/10655280 | status 200
# Loaded 151000/10655280 | status 200
# Loaded 152000/10655280 | status 200
# Loaded 153000/10655280 | status 200
# Loaded 154000/10655280 | status 200
# Loaded 155000/10655280 | status 200
# Loaded 156000/10655280 | status 200
# Loaded 157000/10655280 | status 200
# Loaded 158000/10655280 | status 200
# Loaded 159000/10655280 | status 200
# Loaded 160000/10655280 | status 200
# Loaded 161000/10655280 | status 200
# Loaded 162000/10655280 | status 200
# Loaded 163000/10655280 | status 200
# Loaded 164000/10655280 | status 200
# Loaded 165000/10655280 | status 200
# Loaded 166000/10655280 | status 200
# Loaded 167000/10655280 | status 200
# Loaded 168000/10655280 | status 200
# Loaded 169000/10655280 | status 200
# Loaded 170000/10655280 | status 200
# Loaded 171000/10655280 | status 200
# Loaded 172000/10655280 | status 200
# Loaded 173000/10655280 | status 200
# Loaded 174000/10655280 | status 200
# Loaded 175000/10655280 | status 200
# Loaded 176000/10655280 | status 200
# Loaded 177000/10655280 | status 200
# Loaded 178000/10655280 | status 200
# Loaded 179000/10655280 | status 200
# Loaded 180000/10655280 | status 200
# Loaded 181000/10655280 | status 200
# Loaded 182000/10655280 | status 200
# Loaded 183000/10655280 | status 200
# Loaded 184000/10655280 | status 200
# Loaded 185000/10655280 | status 200
# Loaded 186000/10655280 | status 200
# Loaded 187000/10655280 | status 200
# Loaded 188000/10655280 | status 200
# Loaded 189000/10655280 | status 200
# Loaded 190000/10655280 | status 200
# Loaded 191000/10655280 | status 200
# Loaded 192000/10655280 | status 200
# Loaded 193000/10655280 | status 200
# Loaded 194000/10655280 | status 200
# Loaded 195000/10655280 | status 200
# Loaded 196000/10655280 | status 200
# Loaded 197000/10655280 | status 200
# Loaded 198000/10655280 | status 200
# Loaded 199000/10655280 | status 200
# Loaded 200000/10655280 | status 200
# Loaded 201000/10655280 | status 200
# Loaded 202000/10655280 | status 200
# Loaded 203000/10655280 | status 200
# Loaded 204000/10655280 | status 200
# Loaded 205000/10655280 | status 200
# Loaded 206000/10655280 | status 200
# Loaded 207000/10655280 | status 200
# Loaded 208000/10655280 | status 200
# Loaded 209000/10655280 | status 200
# Loaded 210000/10655280 | status 200
# Loaded 211000/10655280 | status 200
# Loaded 212000/10655280 | status 200
# Loaded 213000/10655280 | status 200
# Loaded 214000/10655280 | status 200
# Loaded 215000/10655280 | status 200
# Loaded 216000/10655280 | status 200
# Loaded 217000/10655280 | status 200
# Loaded 218000/10655280 | status 200
# Loaded 219000/10655280 | status 200
# Loaded 220000/10655280 | status 200
# Loaded 221000/10655280 | status 200
# Loaded 222000/10655280 | status 200
# Loaded 223000/10655280 | status 200
# Loaded 224000/10655280 | status 200
# Loaded 225000/10655280 | status 200
# Loaded 226000/10655280 | status 200
# Loaded 227000/10655280 | status 200
# Loaded 228000/10655280 | status 200
# Loaded 229000/10655280 | status 200
# Loaded 230000/10655280 | status 200
# Loaded 231000/10655280 | status 200
# Loaded 232000/10655280 | status 200
# Loaded 233000/10655280 | status 200
# Loaded 234000/10655280 | status 200
# Loaded 235000/10655280 | status 200
# Loaded 236000/10655280 | status 200
# Loaded 237000/10655280 | status 200
# Loaded 238000/10655280 | status 200
# Loaded 239000/10655280 | status 200
# Loaded 240000/10655280 | status 200
# Loaded 241000/10655280 | status 200
# Loaded 242000/10655280 | status 200
# Loaded 243000/10655280 | status 200
# Loaded 244000/10655280 | status 200
# Loaded 245000/10655280 | status 200
# Loaded 246000/10655280 | status 200
# Loaded 247000/10655280 | status 200
# Loaded 248000/10655280 | status 200
# Loaded 249000/10655280 | status 200
# Loaded 250000/10655280 | status 200
# Loaded 251000/10655280 | status 200
# Loaded 252000/10655280 | status 200
# Loaded 253000/10655280 | status 200
# Loaded 254000/10655280 | status 200
# Loaded 255000/10655280 | status 200
# Loaded 256000/10655280 | status 200
# Loaded 257000/10655280 | status 200
# Loaded 258000/10655280 | status 200
# Loaded 259000/10655280 | status 200
# Loaded 260000/10655280 | status 200
# Loaded 261000/10655280 | status 200
# Loaded 262000/10655280 | status 200
# Loaded 263000/10655280 | status 200
# Loaded 264000/10655280 | status 200
# Loaded 265000/10655280 | status 200
# Loaded 266000/10655280 | status 200
# Loaded 267000/10655280 | status 200
# Loaded 268000/10655280 | status 200
# Loaded 269000/10655280 | status 200
# Loaded 270000/10655280 | status 200
# Loaded 271000/10655280 | status 200
# Loaded 272000/10655280 | status 200
# Loaded 273000/10655280 | status 200
# Loaded 274000/10655280 | status 200
# Loaded 275000/10655280 | status 200
# Loaded 276000/10655280 | status 200
# Loaded 277000/10655280 | status 200
# Loaded 278000/10655280 | status 200
# Loaded 279000/10655280 | status 200
# Loaded 280000/10655280 | status 200
# Loaded 281000/10655280 | status 200
# Loaded 282000/10655280 | status 200
# Loaded 283000/10655280 | status 200
# Loaded 284000/10655280 | status 200
# Loaded 285000/10655280 | status 200
# Loaded 286000/10655280 | status 200
# Loaded 287000/10655280 | status 200
# Loaded 288000/10655280 | status 200
# Loaded 289000/10655280 | status 200
# Loaded 290000/10655280 | status 200
# Loaded 291000/10655280 | status 200
# Loaded 292000/10655280 | status 200
# Loaded 293000/10655280 | status 200
# Loaded 294000/10655280 | status 200
# Loaded 295000/10655280 | status 200
# Loaded 296000/10655280 | status 200
# Loaded 297000/10655280 | status 200
# Loaded 298000/10655280 | status 200
# Loaded 299000/10655280 | status 200
# Loaded 300000/10655280 | status 200
# Loaded 301000/10655280 | status 200
# Loaded 302000/10655280 | status 200
# Loaded 303000/10655280 | status 200
# Loaded 304000/10655280 | status 200
# Loaded 305000/10655280 | status 200
# Loaded 306000/10655280 | status 200
# Loaded 307000/10655280 | status 200
# Loaded 308000/10655280 | status 200
# Loaded 309000/10655280 | status 200
# Loaded 310000/10655280 | status 200
# Loaded 311000/10655280 | status 200
# Loaded 312000/10655280 | status 200
# Loaded 313000/10655280 | status 200
# Loaded 314000/10655280 | status 200
# Loaded 315000/10655280 | status 200
# Loaded 316000/10655280 | status 200
# Loaded 317000/10655280 | status 200
# Loaded 318000/10655280 | status 200
# Loaded 319000/10655280 | status 200
# Loaded 320000/10655280 | status 200
# Loaded 321000/10655280 | status 200
# Loaded 322000/10655280 | status 200
# Loaded 323000/10655280 | status 200
# Loaded 324000/10655280 | status 200
# Loaded 325000/10655280 | status 200
# Loaded 326000/10655280 | status 200
# Loaded 327000/10655280 | status 200
# Loaded 328000/10655280 | status 200
# Loaded 329000/10655280 | status 200
# Loaded 330000/10655280 | status 200
# Loaded 331000/10655280 | status 200
# Loaded 332000/10655280 | status 200
# Loaded 333000/10655280 | status 200
# Loaded 334000/10655280 | status 200
# Loaded 335000/10655280 | status 200
# Loaded 336000/10655280 | status 200
# Loaded 337000/10655280 | status 200
# Loaded 338000/10655280 | status 200
# Loaded 339000/10655280 | status 200
# Loaded 340000/10655280 | status 200
# Loaded 341000/10655280 | status 200
# Loaded 342000/10655280 | status 200
# Loaded 343000/10655280 | status 200
# Loaded 344000/10655280 | status 200
# Loaded 345000/10655280 | status 200
# Loaded 346000/10655280 | status 200
# Loaded 347000/10655280 | status 200
# Loaded 348000/10655280 | status 200
# Loaded 349000/10655280 | status 200
# Loaded 350000/10655280 | status 200
# Loaded 351000/10655280 | status 200
# Loaded 352000/10655280 | status 200
# Loaded 353000/10655280 | status 200
# Loaded 354000/10655280 | status 200
# Loaded 355000/10655280 | status 200
# Loaded 356000/10655280 | status 200
# Loaded 357000/10655280 | status 200
# Loaded 358000/10655280 | status 200
# Loaded 359000/10655280 | status 200
# Loaded 360000/10655280 | status 200
# Loaded 361000/10655280 | status 200
# Loaded 362000/10655280 | status 200
# Loaded 363000/10655280 | status 200
# Loaded 364000/10655280 | status 200
# Loaded 365000/10655280 | status 200
# Loaded 366000/10655280 | status 200
# Loaded 367000/10655280 | status 200
# Loaded 368000/10655280 | status 200
# Loaded 369000/10655280 | status 200
# Loaded 370000/10655280 | status 200
# Loaded 371000/10655280 | status 200
# Loaded 372000/10655280 | status 200
# Loaded 373000/10655280 | status 200
# Loaded 374000/10655280 | status 200
# Loaded 375000/10655280 | status 200
# Loaded 376000/10655280 | status 200
# Loaded 377000/10655280 | status 200
# Loaded 378000/10655280 | status 200
# Loaded 379000/10655280 | status 200
# Loaded 380000/10655280 | status 200
# Loaded 381000/10655280 | status 200
# Loaded 382000/10655280 | status 200
# Loaded 383000/10655280 | status 200
# Loaded 384000/10655280 | status 200
# Loaded 385000/10655280 | status 200
# Loaded 386000/10655280 | status 200
# Loaded 387000/10655280 | status 200
# Loaded 388000/10655280 | status 200
# Loaded 389000/10655280 | status 200
# Loaded 390000/10655280 | status 200
# Loaded 391000/10655280 | status 200
# Loaded 392000/10655280 | status 200
# Loaded 393000/10655280 | status 200
# Loaded 394000/10655280 | status 200
# Loaded 395000/10655280 | status 200
# Loaded 396000/10655280 | status 200
# Loaded 397000/10655280 | status 200
# Loaded 398000/10655280 | status 200
# Loaded 399000/10655280 | status 200
# Loaded 400000/10655280 | status 200
# Loaded 401000/10655280 | status 200
# Loaded 402000/10655280 | status 200
# Loaded 403000/10655280 | status 200
# Loaded 404000/10655280 | status 200
# Loaded 405000/10655280 | status 200
# Loaded 406000/10655280 | status 200
# Loaded 407000/10655280 | status 200
# Loaded 408000/10655280 | status 200
# Loaded 409000/10655280 | status 200
# Loaded 410000/10655280 | status 200
# Loaded 411000/10655280 | status 200
# Loaded 412000/10655280 | status 200
# Loaded 413000/10655280 | status 200
# Loaded 414000/10655280 | status 200
# Loaded 415000/10655280 | status 200
# Loaded 416000/10655280 | status 200
# Loaded 417000/10655280 | status 200
# Loaded 418000/10655280 | status 200
# Loaded 419000/10655280 | status 200
# Loaded 420000/10655280 | status 200
# Loaded 421000/10655280 | status 200
# Loaded 422000/10655280 | status 200
# Loaded 423000/10655280 | status 200
# Loaded 424000/10655280 | status 200
# Loaded 425000/10655280 | status 200
# Loaded 426000/10655280 | status 200
# Loaded 427000/10655280 | status 200
# Loaded 428000/10655280 | status 200
# Loaded 429000/10655280 | status 200
# Loaded 430000/10655280 | status 200
# Loaded 431000/10655280 | status 200
# Loaded 432000/10655280 | status 200
# Loaded 433000/10655280 | status 200
# Loaded 434000/10655280 | status 200
# Loaded 435000/10655280 | status 200
# Loaded 436000/10655280 | status 200
# Loaded 437000/10655280 | status 200
# Loaded 438000/10655280 | status 200
# Loaded 439000/10655280 | status 200
# Loaded 440000/10655280 | status 200
# Loaded 441000/10655280 | status 200
# Loaded 442000/10655280 | status 200
# Loaded 443000/10655280 | status 200
# Loaded 444000/10655280 | status 200
# Loaded 445000/10655280 | status 200
# Loaded 446000/10655280 | status 200
# Loaded 447000/10655280 | status 200
# Loaded 448000/10655280 | status 200
# Loaded 449000/10655280 | status 200
# Loaded 450000/10655280 | status 200
# Loaded 451000/10655280 | status 200
# Loaded 452000/10655280 | status 200
# Loaded 453000/10655280 | status 200
# Loaded 454000/10655280 | status 200
# Loaded 455000/10655280 | status 200
# Loaded 456000/10655280 | status 200
# Loaded 457000/10655280 | status 200
# Loaded 458000/10655280 | status 200
# Loaded 459000/10655280 | status 200
# Loaded 460000/10655280 | status 200
# Loaded 461000/10655280 | status 200
# Loaded 462000/10655280 | status 200
# Loaded 463000/10655280 | status 200
# Loaded 464000/10655280 | status 200
# Loaded 465000/10655280 | status 200
# Loaded 466000/10655280 | status 200
# Loaded 467000/10655280 | status 200
# Loaded 468000/10655280 | status 200
# Loaded 469000/10655280 | status 200
# Loaded 470000/10655280 | status 200
# Loaded 471000/10655280 | status 200
# Loaded 472000/10655280 | status 200
# Loaded 473000/10655280 | status 200
# Loaded 474000/10655280 | status 200
# Loaded 475000/10655280 | status 200
# Loaded 476000/10655280 | status 200
# Loaded 477000/10655280 | status 200
# Loaded 478000/10655280 | status 200
# Loaded 479000/10655280 | status 200
# Loaded 480000/10655280 | status 200
# Loaded 481000/10655280 | status 200
# Loaded 482000/10655280 | status 200
# Loaded 483000/10655280 | status 200
# Loaded 484000/10655280 | status 200
# Loaded 485000/10655280 | status 200
# Loaded 486000/10655280 | status 200
# Loaded 487000/10655280 | status 200
# Loaded 488000/10655280 | status 200
# Loaded 489000/10655280 | status 200
# Loaded 490000/10655280 | status 200
# Loaded 491000/10655280 | status 200
# Loaded 492000/10655280 | status 200
# Loaded 493000/10655280 | status 200
# Loaded 494000/10655280 | status 200
# Loaded 495000/10655280 | status 200
# Loaded 496000/10655280 | status 200
# Loaded 497000/10655280 | status 200
# Loaded 498000/10655280 | status 200
# Loaded 499000/10655280 | status 200
# Loaded 500000/10655280 | status 200
# Loaded 501000/10655280 | status 200
# Loaded 502000/10655280 | status 200
# Loaded 503000/10655280 | status 200
# Loaded 504000/10655280 | status 200
# Loaded 505000/10655280 | status 200
# Loaded 506000/10655280 | status 200
# Loaded 507000/10655280 | status 200
# Loaded 508000/10655280 | status 200
# Loaded 509000/10655280 | status 200
# Loaded 510000/10655280 | status 200
# Loaded 511000/10655280 | status 200
# Loaded 512000/10655280 | status 200
# Loaded 513000/10655280 | status 200
# Loaded 514000/10655280 | status 200
# Loaded 515000/10655280 | status 200
# Loaded 516000/10655280 | status 200
# Loaded 517000/10655280 | status 200
# Loaded 518000/10655280 | status 200
# Loaded 519000/10655280 | status 200
# Loaded 520000/10655280 | status 200
# Loaded 521000/10655280 | status 200
# Loaded 522000/10655280 | status 200
# Loaded 523000/10655280 | status 200
# Loaded 524000/10655280 | status 200
# Loaded 525000/10655280 | status 200
# Loaded 526000/10655280 | status 200
# Loaded 527000/10655280 | status 200
# Loaded 528000/10655280 | status 200
# Loaded 529000/10655280 | status 200
# Loaded 530000/10655280 | status 200
# Loaded 531000/10655280 | status 200
# Loaded 532000/10655280 | status 200
# Loaded 533000/10655280 | status 200
# Loaded 534000/10655280 | status 200
# Loaded 535000/10655280 | status 200
# Loaded 536000/10655280 | status 200
# Loaded 537000/10655280 | status 200
# Loaded 538000/10655280 | status 200
# Loaded 539000/10655280 | status 200
# Loaded 540000/10655280 | status 200
# Loaded 541000/10655280 | status 200
# Loaded 542000/10655280 | status 200
# Loaded 543000/10655280 | status 200
# Loaded 544000/10655280 | status 200
# Loaded 545000/10655280 | status 200
# Loaded 546000/10655280 | status 200
# Loaded 547000/10655280 | status 200
# Loaded 548000/10655280 | status 200
# Loaded 549000/10655280 | status 200
# Loaded 550000/10655280 | status 200
# Loaded 551000/10655280 | status 200
# Loaded 552000/10655280 | status 200
# Loaded 553000/10655280 | status 200
# Loaded 554000/10655280 | status 200
# Loaded 555000/10655280 | status 200
# Loaded 556000/10655280 | status 200
# Loaded 557000/10655280 | status 200
# Loaded 558000/10655280 | status 200
# Loaded 559000/10655280 | status 200
# Loaded 560000/10655280 | status 200
# Loaded 561000/10655280 | status 200
# Loaded 562000/10655280 | status 200
# Loaded 563000/10655280 | status 200
# Loaded 564000/10655280 | status 200
# Loaded 565000/10655280 | status 200
# Loaded 566000/10655280 | status 200
# Loaded 567000/10655280 | status 200
# Loaded 568000/10655280 | status 200
# Loaded 569000/10655280 | status 200
# Loaded 570000/10655280 | status 200
# Loaded 571000/10655280 | status 200
# Loaded 572000/10655280 | status 200
# Loaded 573000/10655280 | status 200
# Loaded 574000/10655280 | status 200
# Loaded 575000/10655280 | status 200
# Loaded 576000/10655280 | status 200
# Loaded 577000/10655280 | status 200
# Loaded 578000/10655280 | status 200
# Loaded 579000/10655280 | status 200
# Loaded 580000/10655280 | status 200
# Loaded 581000/10655280 | status 200
# Loaded 582000/10655280 | status 200
# Loaded 583000/10655280 | status 200
# Loaded 584000/10655280 | status 200
# Loaded 585000/10655280 | status 200
# Loaded 586000/10655280 | status 200
# Loaded 587000/10655280 | status 200
# Loaded 588000/10655280 | status 200
# Loaded 589000/10655280 | status 200
# Loaded 590000/10655280 | status 200
# Loaded 591000/10655280 | status 200
# Loaded 592000/10655280 | status 200
# Loaded 593000/10655280 | status 200
# Loaded 594000/10655280 | status 200
# Loaded 595000/10655280 | status 200
# Loaded 596000/10655280 | status 200
# Loaded 597000/10655280 | status 200
# Loaded 598000/10655280 | status 200
# Loaded 599000/10655280 | status 200
# Loaded 600000/10655280 | status 200
# Loaded 601000/10655280 | status 200
# Loaded 602000/10655280 | status 200
# Loaded 603000/10655280 | status 200
# Loaded 604000/10655280 | status 200
# Loaded 605000/10655280 | status 200
# Loaded 606000/10655280 | status 200
# Loaded 607000/10655280 | status 200
# Loaded 608000/10655280 | status 200
# Loaded 609000/10655280 | status 200
# Loaded 610000/10655280 | status 200
# Loaded 611000/10655280 | status 200
# Loaded 612000/10655280 | status 200
# Loaded 613000/10655280 | status 200
# Loaded 614000/10655280 | status 200
# Loaded 615000/10655280 | status 200
# Loaded 616000/10655280 | status 200
# Loaded 617000/10655280 | status 200
# Loaded 618000/10655280 | status 200
# Loaded 619000/10655280 | status 200
# Loaded 620000/10655280 | status 200
# Loaded 621000/10655280 | status 200
# Loaded 622000/10655280 | status 200
# Loaded 623000/10655280 | status 200
# Loaded 624000/10655280 | status 200
# Loaded 625000/10655280 | status 200
# Loaded 626000/10655280 | status 200
# Loaded 627000/10655280 | status 200
# Loaded 628000/10655280 | status 200
# Loaded 629000/10655280 | status 200
# Loaded 630000/10655280 | status 200
# Loaded 631000/10655280 | status 200
# Loaded 632000/10655280 | status 200
# Loaded 633000/10655280 | status 200
# Loaded 634000/10655280 | status 200
# Loaded 635000/10655280 | status 200
# Loaded 636000/10655280 | status 200
# Loaded 637000/10655280 | status 200
# Loaded 638000/10655280 | status 200
# Loaded 639000/10655280 | status 200
# Loaded 640000/10655280 | status 200
# Loaded 641000/10655280 | status 200
# Loaded 642000/10655280 | status 200
# Loaded 643000/10655280 | status 200
# Loaded 644000/10655280 | status 200
# Loaded 645000/10655280 | status 200
# Loaded 646000/10655280 | status 200
# Loaded 647000/10655280 | status 200
# Loaded 648000/10655280 | status 200
# Loaded 649000/10655280 | status 200
# Loaded 650000/10655280 | status 200
# Loaded 651000/10655280 | status 200
# Loaded 652000/10655280 | status 200
# Loaded 653000/10655280 | status 200
# Loaded 654000/10655280 | status 200
# Loaded 655000/10655280 | status 200
# Loaded 656000/10655280 | status 200
# Loaded 657000/10655280 | status 200
# Loaded 658000/10655280 | status 200
# Loaded 659000/10655280 | status 200
# Loaded 660000/10655280 | status 200
# Loaded 661000/10655280 | status 200
# Loaded 662000/10655280 | status 200
# Loaded 663000/10655280 | status 200
# Loaded 664000/10655280 | status 200
# Loaded 665000/10655280 | status 200
# Loaded 666000/10655280 | status 200
# Loaded 667000/10655280 | status 200
# Loaded 668000/10655280 | status 200
# Loaded 669000/10655280 | status 200
# Loaded 670000/10655280 | status 200
# Loaded 671000/10655280 | status 200
# Loaded 672000/10655280 | status 200
# Loaded 673000/10655280 | status 200
# Loaded 674000/10655280 | status 200
# Loaded 675000/10655280 | status 200
# Loaded 676000/10655280 | status 200
# Loaded 677000/10655280 | status 200
# Loaded 678000/10655280 | status 200
# Loaded 679000/10655280 | status 200
# Loaded 680000/10655280 | status 200
# Loaded 681000/10655280 | status 200
# Loaded 682000/10655280 | status 200
# Loaded 683000/10655280 | status 200
# Loaded 684000/10655280 | status 200
# Loaded 685000/10655280 | status 200
# Loaded 686000/10655280 | status 200
# Loaded 687000/10655280 | status 200
# Loaded 688000/10655280 | status 200
# Loaded 689000/10655280 | status 200
# Loaded 690000/10655280 | status 200
# Loaded 691000/10655280 | status 200
# Loaded 692000/10655280 | status 200
# Loaded 693000/10655280 | status 200
# Loaded 694000/10655280 | status 200
# Loaded 695000/10655280 | status 200
# Loaded 696000/10655280 | status 200
# Loaded 697000/10655280 | status 200
# Loaded 698000/10655280 | status 200
# Loaded 699000/10655280 | status 200
# Loaded 700000/10655280 | status 200
# Loaded 701000/10655280 | status 200
# Loaded 702000/10655280 | status 200
# Loaded 703000/10655280 | status 200
# Loaded 704000/10655280 | status 200
# Loaded 705000/10655280 | status 200
# Loaded 706000/10655280 | status 200
# Loaded 707000/10655280 | status 200
# Loaded 708000/10655280 | status 200
# Loaded 709000/10655280 | status 200
# Loaded 710000/10655280 | status 200
# Loaded 711000/10655280 | status 200
# Loaded 712000/10655280 | status 200
# Loaded 713000/10655280 | status 200
# Loaded 714000/10655280 | status 200
# Loaded 715000/10655280 | status 200
# Loaded 716000/10655280 | status 200
# Loaded 717000/10655280 | status 200
# Loaded 718000/10655280 | status 200
# Loaded 719000/10655280 | status 200
# Loaded 720000/10655280 | status 200
# Loaded 721000/10655280 | status 200
# Loaded 722000/10655280 | status 200
# Loaded 723000/10655280 | status 200
# Loaded 724000/10655280 | status 200
# Loaded 725000/10655280 | status 200
# Loaded 726000/10655280 | status 200
# Loaded 727000/10655280 | status 200
# Loaded 728000/10655280 | status 200
# Loaded 729000/10655280 | status 200
# Loaded 730000/10655280 | status 200
# Loaded 731000/10655280 | status 200
# Loaded 732000/10655280 | status 200
# Loaded 733000/10655280 | status 200
# Loaded 734000/10655280 | status 200
# Loaded 735000/10655280 | status 200
# Loaded 736000/10655280 | status 200
# Loaded 737000/10655280 | status 200
# Loaded 738000/10655280 | status 200
# Loaded 739000/10655280 | status 200
# Loaded 740000/10655280 | status 200
# Loaded 741000/10655280 | status 200
# Loaded 742000/10655280 | status 200
# Loaded 743000/10655280 | status 200
# Loaded 744000/10655280 | status 200
# Loaded 745000/10655280 | status 200
# Loaded 746000/10655280 | status 200
# Loaded 747000/10655280 | status 200
# Loaded 748000/10655280 | status 200
# Loaded 749000/10655280 | status 200
# Loaded 750000/10655280 | status 200
# Loaded 751000/10655280 | status 200
# Loaded 752000/10655280 | status 200
# Loaded 753000/10655280 | status 200
# Loaded 754000/10655280 | status 200
# Loaded 755000/10655280 | status 200
# Loaded 756000/10655280 | status 200
# Loaded 757000/10655280 | status 200
# Loaded 758000/10655280 | status 200
# Loaded 759000/10655280 | status 200
# Loaded 760000/10655280 | status 200
# Loaded 761000/10655280 | status 200
# Loaded 762000/10655280 | status 200
# Loaded 763000/10655280 | status 200
# Loaded 764000/10655280 | status 200
# Loaded 765000/10655280 | status 200
# Loaded 766000/10655280 | status 200
# Loaded 767000/10655280 | status 200
# Loaded 768000/10655280 | status 200
# Loaded 769000/10655280 | status 200
# Loaded 770000/10655280 | status 200
# Loaded 771000/10655280 | status 200
# Loaded 772000/10655280 | status 200
# Loaded 773000/10655280 | status 200
# Loaded 774000/10655280 | status 200
# Loaded 775000/10655280 | status 200
# Loaded 776000/10655280 | status 200
# Loaded 777000/10655280 | status 200
# Loaded 778000/10655280 | status 200
# Loaded 779000/10655280 | status 200
# Loaded 780000/10655280 | status 200
# Loaded 781000/10655280 | status 200
# Loaded 782000/10655280 | status 200
# Loaded 783000/10655280 | status 200
# Loaded 784000/10655280 | status 200
# Loaded 785000/10655280 | status 200
# Loaded 786000/10655280 | status 200
# Loaded 787000/10655280 | status 200
# Loaded 788000/10655280 | status 200
# Loaded 789000/10655280 | status 200
# Loaded 790000/10655280 | status 200
# Loaded 791000/10655280 | status 200
# Loaded 792000/10655280 | status 200
# Loaded 793000/10655280 | status 200
# Loaded 794000/10655280 | status 200
# Loaded 795000/10655280 | status 200
# Loaded 796000/10655280 | status 200
# Loaded 797000/10655280 | status 200
# Loaded 798000/10655280 | status 200
# Loaded 799000/10655280 | status 200
# Loaded 800000/10655280 | status 200
# Loaded 801000/10655280 | status 200
# Loaded 802000/10655280 | status 200
# Loaded 803000/10655280 | status 200
# Loaded 804000/10655280 | status 200
# Loaded 805000/10655280 | status 200
# Loaded 806000/10655280 | status 200
# Loaded 807000/10655280 | status 200
# Loaded 808000/10655280 | status 200
# Loaded 809000/10655280 | status 200
# Loaded 810000/10655280 | status 200
# Loaded 811000/10655280 | status 200
# Loaded 812000/10655280 | status 200
# Loaded 813000/10655280 | status 200
# Loaded 814000/10655280 | status 200
# Loaded 815000/10655280 | status 200
# Loaded 816000/10655280 | status 200
# Loaded 817000/10655280 | status 200
# Loaded 818000/10655280 | status 200
# Loaded 819000/10655280 | status 200
# Loaded 820000/10655280 | status 200
# Loaded 821000/10655280 | status 200
# Loaded 822000/10655280 | status 200
# Loaded 823000/10655280 | status 200
# Loaded 824000/10655280 | status 200
# Loaded 825000/10655280 | status 200
# Loaded 826000/10655280 | status 200
# Loaded 827000/10655280 | status 200
# Loaded 828000/10655280 | status 200
# Loaded 829000/10655280 | status 200
# Loaded 830000/10655280 | status 200
# Loaded 831000/10655280 | status 200
# Loaded 832000/10655280 | status 200
# Loaded 833000/10655280 | status 200
# Loaded 834000/10655280 | status 200
# Loaded 835000/10655280 | status 200
# Loaded 836000/10655280 | status 200
# Loaded 837000/10655280 | status 200
# Loaded 838000/10655280 | status 200
# Loaded 839000/10655280 | status 200
# Loaded 840000/10655280 | status 200
# Loaded 841000/10655280 | status 200
# Loaded 842000/10655280 | status 200
# Loaded 843000/10655280 | status 200
# Loaded 844000/10655280 | status 200
# Loaded 845000/10655280 | status 200
# Loaded 846000/10655280 | status 200
# Loaded 847000/10655280 | status 200
# Loaded 848000/10655280 | status 200
# Loaded 849000/10655280 | status 200
# Loaded 850000/10655280 | status 200
# Loaded 851000/10655280 | status 200
# Loaded 852000/10655280 | status 200
# Loaded 853000/10655280 | status 200
# Loaded 854000/10655280 | status 200
# Loaded 855000/10655280 | status 200
# Loaded 856000/10655280 | status 200
# Loaded 857000/10655280 | status 200
# Loaded 858000/10655280 | status 200
# Loaded 859000/10655280 | status 200
# Loaded 860000/10655280 | status 200
# Loaded 861000/10655280 | status 200
# Loaded 862000/10655280 | status 200
# Loaded 863000/10655280 | status 200
# Loaded 864000/10655280 | status 200
# Loaded 865000/10655280 | status 200
# Loaded 866000/10655280 | status 200
# Loaded 867000/10655280 | status 200
# Loaded 868000/10655280 | status 200
# Loaded 869000/10655280 | status 200
# Loaded 870000/10655280 | status 200
# Loaded 871000/10655280 | status 200
# Loaded 872000/10655280 | status 200
# Loaded 873000/10655280 | status 200
# Loaded 874000/10655280 | status 200
# Loaded 875000/10655280 | status 200
# Loaded 876000/10655280 | status 200
# Loaded 877000/10655280 | status 200
# Loaded 878000/10655280 | status 200
# Loaded 879000/10655280 | status 200
# Loaded 880000/10655280 | status 200
# Loaded 881000/10655280 | status 200
# Loaded 882000/10655280 | status 200
# Loaded 883000/10655280 | status 200
# Loaded 884000/10655280 | status 200
# Loaded 885000/10655280 | status 200
# Loaded 886000/10655280 | status 200
# Loaded 887000/10655280 | status 200
# Loaded 888000/10655280 | status 200
# Loaded 889000/10655280 | status 200
# Loaded 890000/10655280 | status 200
# Loaded 891000/10655280 | status 200
# Loaded 892000/10655280 | status 200
# Loaded 893000/10655280 | status 200
# Loaded 894000/10655280 | status 200
# Loaded 895000/10655280 | status 200
# Loaded 896000/10655280 | status 200
# Loaded 897000/10655280 | status 200
# Loaded 898000/10655280 | status 200
# Loaded 899000/10655280 | status 200
# Loaded 900000/10655280 | status 200
# Loaded 901000/10655280 | status 200
# Loaded 902000/10655280 | status 200
# Loaded 903000/10655280 | status 200
# Loaded 904000/10655280 | status 200
# Loaded 905000/10655280 | status 200
# Loaded 906000/10655280 | status 200
# Loaded 907000/10655280 | status 200
# Loaded 908000/10655280 | status 200
# Loaded 909000/10655280 | status 200
# Loaded 910000/10655280 | status 200
# Loaded 911000/10655280 | status 200
# Loaded 912000/10655280 | status 200
# Loaded 913000/10655280 | status 200
# Loaded 914000/10655280 | status 200
# Loaded 915000/10655280 | status 200
# Loaded 916000/10655280 | status 200
# Loaded 917000/10655280 | status 200
# Loaded 918000/10655280 | status 200
# Loaded 919000/10655280 | status 200
# Loaded 920000/10655280 | status 200
# Loaded 921000/10655280 | status 200
# Loaded 922000/10655280 | status 200
# Loaded 923000/10655280 | status 200
# Loaded 924000/10655280 | status 200
# Loaded 925000/10655280 | status 200
# Loaded 926000/10655280 | status 200
# Loaded 927000/10655280 | status 200
# Loaded 928000/10655280 | status 200
# Loaded 929000/10655280 | status 200
# Loaded 930000/10655280 | status 200
# Loaded 931000/10655280 | status 200
# Loaded 932000/10655280 | status 200
# Loaded 933000/10655280 | status 200
# Loaded 934000/10655280 | status 200
# Loaded 935000/10655280 | status 200
# Loaded 936000/10655280 | status 200
# Loaded 937000/10655280 | status 200
# Loaded 938000/10655280 | status 200
# Loaded 939000/10655280 | status 200
# Loaded 940000/10655280 | status 200
# Loaded 941000/10655280 | status 200
# Loaded 942000/10655280 | status 200
# Loaded 943000/10655280 | status 200
# Loaded 944000/10655280 | status 200
# Loaded 945000/10655280 | status 200
# Loaded 946000/10655280 | status 200
# Loaded 947000/10655280 | status 200
# Loaded 948000/10655280 | status 200
# Loaded 949000/10655280 | status 200
# Loaded 950000/10655280 | status 200
# Loaded 951000/10655280 | status 200
# Loaded 952000/10655280 | status 200
# Loaded 953000/10655280 | status 200
# Loaded 954000/10655280 | status 200
# Loaded 955000/10655280 | status 200
# Loaded 956000/10655280 | status 200
# Loaded 957000/10655280 | status 200
# Loaded 958000/10655280 | status 200
# Loaded 959000/10655280 | status 200
# Loaded 960000/10655280 | status 200
# Loaded 961000/10655280 | status 200
# Loaded 962000/10655280 | status 200
# Loaded 963000/10655280 | status 200
# Loaded 964000/10655280 | status 200
# Loaded 965000/10655280 | status 200
# Loaded 966000/10655280 | status 200
# Loaded 967000/10655280 | status 200
# Loaded 968000/10655280 | status 200
# Loaded 969000/10655280 | status 200
# Loaded 970000/10655280 | status 200
# Loaded 971000/10655280 | status 200
# Loaded 972000/10655280 | status 200
# Loaded 973000/10655280 | status 200
# Loaded 974000/10655280 | status 200
# Loaded 975000/10655280 | status 200
# Loaded 976000/10655280 | status 200
# Loaded 977000/10655280 | status 200
# Loaded 978000/10655280 | status 200
# Loaded 979000/10655280 | status 200
# Loaded 980000/10655280 | status 200
# Loaded 981000/10655280 | status 200
# Loaded 982000/10655280 | status 200
# Loaded 983000/10655280 | status 200
# Loaded 984000/10655280 | status 200
# Loaded 985000/10655280 | status 200
# Loaded 986000/10655280 | status 200
# Loaded 987000/10655280 | status 200
# Loaded 988000/10655280 | status 200
# Loaded 989000/10655280 | status 200
# Loaded 990000/10655280 | status 200
# Loaded 991000/10655280 | status 200
# Loaded 992000/10655280 | status 200
# Loaded 993000/10655280 | status 200
# Loaded 994000/10655280 | status 200
# Loaded 995000/10655280 | status 200
# Loaded 996000/10655280 | status 200
# Loaded 997000/10655280 | status 200
# Loaded 998000/10655280 | status 200
# Loaded 999000/10655280 | status 200
# Loaded 1000000/10655280 | status 200
# Loaded 1001000/10655280 | status 200
# Loaded 1002000/10655280 | status 200
# Loaded 1003000/10655280 | status 200
# Loaded 1004000/10655280 | status 200
# Loaded 1005000/10655280 | status 200
# Loaded 1006000/10655280 | status 200
# Loaded 1007000/10655280 | status 200
# Loaded 1008000/10655280 | status 200
# Loaded 1009000/10655280 | status 200
# Loaded 1010000/10655280 | status 200
# Loaded 1011000/10655280 | status 200
# Loaded 1012000/10655280 | status 200
# Loaded 1013000/10655280 | status 200
# Loaded 1014000/10655280 | status 200
# Loaded 1015000/10655280 | status 200
# Loaded 1016000/10655280 | status 200
# Loaded 1017000/10655280 | status 200
# Loaded 1018000/10655280 | status 200
# Loaded 1019000/10655280 | status 200
# Loaded 1020000/10655280 | status 200
# Loaded 1021000/10655280 | status 200
# Loaded 1022000/10655280 | status 200
# Loaded 1023000/10655280 | status 200
# Loaded 1024000/10655280 | status 200
# Loaded 1025000/10655280 | status 200
# Loaded 1026000/10655280 | status 200
# Loaded 1027000/10655280 | status 200
# Loaded 1028000/10655280 | status 200
# Loaded 1029000/10655280 | status 200
# Loaded 1030000/10655280 | status 200
# Loaded 1031000/10655280 | status 200
# Loaded 1032000/10655280 | status 200
# Loaded 1033000/10655280 | status 200
# Loaded 1034000/10655280 | status 200
# Loaded 1035000/10655280 | status 200
# Loaded 1036000/10655280 | status 200
# Loaded 1037000/10655280 | status 200
# Loaded 1038000/10655280 | status 200
# Loaded 1039000/10655280 | status 200
# Loaded 1040000/10655280 | status 200
# Loaded 1041000/10655280 | status 200
# Loaded 1042000/10655280 | status 200
# Loaded 1043000/10655280 | status 200
# Loaded 1044000/10655280 | status 200
# Loaded 1045000/10655280 | status 200
# Loaded 1046000/10655280 | status 200
# Loaded 1047000/10655280 | status 200
# Loaded 1048000/10655280 | status 200
# Loaded 1049000/10655280 | status 200
# Loaded 1050000/10655280 | status 200
# Loaded 1051000/10655280 | status 200
# Loaded 1052000/10655280 | status 200
# Loaded 1053000/10655280 | status 200
# Loaded 1054000/10655280 | status 200
# Loaded 1055000/10655280 | status 200
# Loaded 1056000/10655280 | status 200
# Loaded 1057000/10655280 | status 200
# Loaded 1058000/10655280 | status 200
# Loaded 1059000/10655280 | status 200
# Loaded 1060000/10655280 | status 200
# Loaded 1061000/10655280 | status 200
# Loaded 1062000/10655280 | status 200
# Loaded 1063000/10655280 | status 200
# Loaded 1064000/10655280 | status 200
# Loaded 1065000/10655280 | status 200
# Loaded 1066000/10655280 | status 200
# Loaded 1067000/10655280 | status 200
# Loaded 1068000/10655280 | status 200
# Loaded 1069000/10655280 | status 200
# Loaded 1070000/10655280 | status 200
# Loaded 1071000/10655280 | status 200
# Loaded 1072000/10655280 | status 200
# Loaded 1073000/10655280 | status 200
# Loaded 1074000/10655280 | status 200
# Loaded 1075000/10655280 | status 200
# Loaded 1076000/10655280 | status 200
# Loaded 1077000/10655280 | status 200
# Loaded 1078000/10655280 | status 200
# Loaded 1079000/10655280 | status 200
# Loaded 1080000/10655280 | status 200
# Loaded 1081000/10655280 | status 200
# Loaded 1082000/10655280 | status 200
# Loaded 1083000/10655280 | status 200
# Loaded 1084000/10655280 | status 200
# Loaded 1085000/10655280 | status 200
# Loaded 1086000/10655280 | status 200
# Loaded 1087000/10655280 | status 200
# Loaded 1088000/10655280 | status 200
# Loaded 1089000/10655280 | status 200
# Loaded 1090000/10655280 | status 200
# Loaded 1091000/10655280 | status 200
# Loaded 1092000/10655280 | status 200
# Loaded 1093000/10655280 | status 200
# Loaded 1094000/10655280 | status 200
# Loaded 1095000/10655280 | status 200
# Loaded 1096000/10655280 | status 200
# Loaded 1097000/10655280 | status 200
# Loaded 1098000/10655280 | status 200
# Loaded 1099000/10655280 | status 200
# Loaded 1100000/10655280 | status 200
# Loaded 1101000/10655280 | status 200
# Loaded 1102000/10655280 | status 200
# Loaded 1103000/10655280 | status 200
# Loaded 1104000/10655280 | status 200
# Loaded 1105000/10655280 | status 200
# Loaded 1106000/10655280 | status 200
# Loaded 1107000/10655280 | status 200
# Loaded 1108000/10655280 | status 200
# Loaded 1109000/10655280 | status 200
# Loaded 1110000/10655280 | status 200
# Loaded 1111000/10655280 | status 200
# Loaded 1112000/10655280 | status 200
# Loaded 1113000/10655280 | status 200
# Loaded 1114000/10655280 | status 200
# Loaded 1115000/10655280 | status 200
# Loaded 1116000/10655280 | status 200
# Loaded 1117000/10655280 | status 200
# Loaded 1118000/10655280 | status 200
# Loaded 1119000/10655280 | status 200
# Loaded 1120000/10655280 | status 200
# Loaded 1121000/10655280 | status 200
# Loaded 1122000/10655280 | status 200
# Loaded 1123000/10655280 | status 200
# Loaded 1124000/10655280 | status 200
# Loaded 1125000/10655280 | status 200
# Loaded 1126000/10655280 | status 200
# Loaded 1127000/10655280 | status 200
# Loaded 1128000/10655280 | status 200
# Loaded 1129000/10655280 | status 200
# Loaded 1130000/10655280 | status 200
# Loaded 1131000/10655280 | status 200
# Loaded 1132000/10655280 | status 200
# Loaded 1133000/10655280 | status 200
# Loaded 1134000/10655280 | status 200
# Loaded 1135000/10655280 | status 200
# Loaded 1136000/10655280 | status 200
# Loaded 1137000/10655280 | status 200
# Loaded 1138000/10655280 | status 200
# Loaded 1139000/10655280 | status 200
# Loaded 1140000/10655280 | status 200
# Loaded 1141000/10655280 | status 200
# Loaded 1142000/10655280 | status 200
# Loaded 1143000/10655280 | status 200
# Loaded 1144000/10655280 | status 200
# Loaded 1145000/10655280 | status 200
# Loaded 1146000/10655280 | status 200
# Loaded 1147000/10655280 | status 200
# Loaded 1148000/10655280 | status 200
# Loaded 1149000/10655280 | status 200
# Loaded 1150000/10655280 | status 200
# Loaded 1151000/10655280 | status 200
# Loaded 1152000/10655280 | status 200
# Loaded 1153000/10655280 | status 200
# Loaded 1154000/10655280 | status 200
# Loaded 1155000/10655280 | status 200
# Loaded 1156000/10655280 | status 200
# Loaded 1157000/10655280 | status 200
# Loaded 1158000/10655280 | status 200
# Loaded 1159000/10655280 | status 200
# Loaded 1160000/10655280 | status 200
# Loaded 1161000/10655280 | status 200
# Loaded 1162000/10655280 | status 200
# Loaded 1163000/10655280 | status 200
# Loaded 1164000/10655280 | status 200
# Loaded 1165000/10655280 | status 200
# Loaded 1166000/10655280 | status 200
# Loaded 1167000/10655280 | status 200
# Loaded 1168000/10655280 | status 200
# Loaded 1169000/10655280 | status 200
# Loaded 1170000/10655280 | status 200
# Loaded 1171000/10655280 | status 200
# Loaded 1172000/10655280 | status 200
# Loaded 1173000/10655280 | status 200
# Loaded 1174000/10655280 | status 200
# Loaded 1175000/10655280 | status 200
# Loaded 1176000/10655280 | status 200
# Loaded 1177000/10655280 | status 200
# Loaded 1178000/10655280 | status 200
# Loaded 1179000/10655280 | status 200
# Loaded 1180000/10655280 | status 200
# Loaded 1181000/10655280 | status 200
# Loaded 1182000/10655280 | status 200
# Loaded 1183000/10655280 | status 200
# Loaded 1184000/10655280 | status 200
# Loaded 1185000/10655280 | status 200
# Loaded 1186000/10655280 | status 200
# Loaded 1187000/10655280 | status 200
# Loaded 1188000/10655280 | status 200
# Loaded 1189000/10655280 | status 200
# Loaded 1190000/10655280 | status 200
# Loaded 1191000/10655280 | status 200
# Loaded 1192000/10655280 | status 200
# Loaded 1193000/10655280 | status 200
# Loaded 1194000/10655280 | status 200
# Loaded 1195000/10655280 | status 200
# Loaded 1196000/10655280 | status 200
# Loaded 1197000/10655280 | status 200
# Loaded 1198000/10655280 | status 200
# Loaded 1199000/10655280 | status 200
# Loaded 1200000/10655280 | status 200
# Loaded 1201000/10655280 | status 200
# Loaded 1202000/10655280 | status 200
# Loaded 1203000/10655280 | status 200
# Loaded 1204000/10655280 | status 200
# Loaded 1205000/10655280 | status 200
# Loaded 1206000/10655280 | status 200
# Loaded 1207000/10655280 | status 200
# Loaded 1208000/10655280 | status 200
# Loaded 1209000/10655280 | status 200
# Loaded 1210000/10655280 | status 200
# Loaded 1211000/10655280 | status 200
# Loaded 1212000/10655280 | status 200
# Loaded 1213000/10655280 | status 200
# Loaded 1214000/10655280 | status 200
# Loaded 1215000/10655280 | status 200
# Loaded 1216000/10655280 | status 200
# Loaded 1217000/10655280 | status 200
# Loaded 1218000/10655280 | status 200
# Loaded 1219000/10655280 | status 200
# Loaded 1220000/10655280 | status 200
# Loaded 1221000/10655280 | status 200
# Loaded 1222000/10655280 | status 200
# Loaded 1223000/10655280 | status 200
# Loaded 1224000/10655280 | status 200
# Loaded 1225000/10655280 | status 200
# Loaded 1226000/10655280 | status 200
# Loaded 1227000/10655280 | status 200
# Loaded 1228000/10655280 | status 200
# Loaded 1229000/10655280 | status 200
# Loaded 1230000/10655280 | status 200
# Loaded 1231000/10655280 | status 200
# Loaded 1232000/10655280 | status 200
# Loaded 1233000/10655280 | status 200
# Loaded 1234000/10655280 | status 200
# Loaded 1235000/10655280 | status 200
# Loaded 1236000/10655280 | status 200
# Loaded 1237000/10655280 | status 200
# Loaded 1238000/10655280 | status 200
# Loaded 1239000/10655280 | status 200
# Loaded 1240000/10655280 | status 200
# Loaded 1241000/10655280 | status 200
# Loaded 1242000/10655280 | status 200
# Loaded 1243000/10655280 | status 200
# Loaded 1244000/10655280 | status 200
# Loaded 1245000/10655280 | status 200
# Loaded 1246000/10655280 | status 200
# Loaded 1247000/10655280 | status 200
# Loaded 1248000/10655280 | status 200
# Loaded 1249000/10655280 | status 200
# Loaded 1250000/10655280 | status 200
# Loaded 1251000/10655280 | status 200
# Loaded 1252000/10655280 | status 200
# Loaded 1253000/10655280 | status 200
# Loaded 1254000/10655280 | status 200
# Loaded 1255000/10655280 | status 200
# Loaded 1256000/10655280 | status 200
# Loaded 1257000/10655280 | status 200
# Loaded 1258000/10655280 | status 200
# Loaded 1259000/10655280 | status 200
# Loaded 1260000/10655280 | status 200
# Loaded 1261000/10655280 | status 200
# Loaded 1262000/10655280 | status 200
# Loaded 1263000/10655280 | status 200
# Loaded 1264000/10655280 | status 200
# Loaded 1265000/10655280 | status 200
# Loaded 1266000/10655280 | status 200
# Loaded 1267000/10655280 | status 200
# Loaded 1268000/10655280 | status 200
# Loaded 1269000/10655280 | status 200
# Loaded 1270000/10655280 | status 200
# Loaded 1271000/10655280 | status 200
# Loaded 1272000/10655280 | status 200
# Loaded 1273000/10655280 | status 200
# Loaded 1274000/10655280 | status 200
# Loaded 1275000/10655280 | status 200
# Loaded 1276000/10655280 | status 200
# Loaded 1277000/10655280 | status 200
# Loaded 1278000/10655280 | status 200
# Loaded 1279000/10655280 | status 200
# Loaded 1280000/10655280 | status 200
# Loaded 1281000/10655280 | status 200
# Loaded 1282000/10655280 | status 200
# Loaded 1283000/10655280 | status 200
# Loaded 1284000/10655280 | status 200
# Loaded 1285000/10655280 | status 200
# Loaded 1286000/10655280 | status 200
# Loaded 1287000/10655280 | status 200
# Loaded 1288000/10655280 | status 200
# Loaded 1289000/10655280 | status 200
# Loaded 1290000/10655280 | status 200
# Loaded 1291000/10655280 | status 200
# Loaded 1292000/10655280 | status 200
# Loaded 1293000/10655280 | status 200
# Loaded 1294000/10655280 | status 200
# Loaded 1295000/10655280 | status 200
# Loaded 1296000/10655280 | status 200
# Loaded 1297000/10655280 | status 200
# Loaded 1298000/10655280 | status 200
# Loaded 1299000/10655280 | status 200
# Loaded 1300000/10655280 | status 200
# Loaded 1301000/10655280 | status 200
# Loaded 1302000/10655280 | status 200
# Loaded 1303000/10655280 | status 200
# Loaded 1304000/10655280 | status 200
# Loaded 1305000/10655280 | status 200
# Loaded 1306000/10655280 | status 200
# Loaded 1307000/10655280 | status 200
# Loaded 1308000/10655280 | status 200
# Loaded 1309000/10655280 | status 200
# Loaded 1310000/10655280 | status 200
# Loaded 1311000/10655280 | status 200
# Loaded 1312000/10655280 | status 200
# Loaded 1313000/10655280 | status 200
# Loaded 1314000/10655280 | status 200
# Loaded 1315000/10655280 | status 200
# Loaded 1316000/10655280 | status 200
# Loaded 1317000/10655280 | status 200
# Loaded 1318000/10655280 | status 200
# Loaded 1319000/10655280 | status 200
# Loaded 1320000/10655280 | status 200
# Loaded 1321000/10655280 | status 200
# Loaded 1322000/10655280 | status 200
# Loaded 1323000/10655280 | status 200
# Loaded 1324000/10655280 | status 200
# Loaded 1325000/10655280 | status 200
# ...
# Loaded 10236000/10655280 | status 200
# Loaded 10237000/10655280 | status 200
# Loaded 10238000/10655280 | status 200
# Loaded 10239000/10655280 | status 200
# Loaded 10240000/10655280 | status 200
# Loaded 10241000/10655280 | status 200
# Loaded 10242000/10655280 | status 200
# Loaded 10243000/10655280 | status 200
# Loaded 10244000/10655280 | status 200
# Loaded 10245000/10655280 | status 200
# Loaded 10246000/10655280 | status 200
# Loaded 10247000/10655280 | status 200
# Loaded 10248000/10655280 | status 200
# Loaded 10249000/10655280 | status 200
# Loaded 10250000/10655280 | status 200
# Loaded 10251000/10655280 | status 200
# Loaded 10252000/10655280 | status 200
# Loaded 10253000/10655280 | status 200
# Loaded 10254000/10655280 | status 200
# Loaded 10255000/10655280 | status 200
# Loaded 10256000/10655280 | status 200
# Loaded 10257000/10655280 | status 200
# Loaded 10258000/10655280 | status 200
# Loaded 10259000/10655280 | status 200
# Loaded 10260000/10655280 | status 200
# Loaded 10261000/10655280 | status 200
# Loaded 10262000/10655280 | status 200
# Loaded 10263000/10655280 | status 200
# Loaded 10264000/10655280 | status 200
# Loaded 10265000/10655280 | status 200
# Loaded 10266000/10655280 | status 200
# Loaded 10267000/10655280 | status 200
# Loaded 10268000/10655280 | status 200
# Loaded 10269000/10655280 | status 200
# Loaded 10270000/10655280 | status 200
# Loaded 10271000/10655280 | status 200
# Loaded 10272000/10655280 | status 200
# Loaded 10273000/10655280 | status 200
# Loaded 10274000/10655280 | status 200
# Loaded 10275000/10655280 | status 200
# Loaded 10276000/10655280 | status 200
# Loaded 10277000/10655280 | status 200
# Loaded 10278000/10655280 | status 200
# Loaded 10279000/10655280 | status 200
# Loaded 10280000/10655280 | status 200
# Loaded 10281000/10655280 | status 200
# Loaded 10282000/10655280 | status 200
# Loaded 10283000/10655280 | status 200
# Loaded 10284000/10655280 | status 200
# Loaded 10285000/10655280 | status 200
# Loaded 10286000/10655280 | status 200
# Loaded 10287000/10655280 | status 200
# Loaded 10288000/10655280 | status 200
# Loaded 10289000/10655280 | status 200
# Loaded 10290000/10655280 | status 200
# Loaded 10291000/10655280 | status 200
# Loaded 10292000/10655280 | status 200
# Loaded 10293000/10655280 | status 200
# Loaded 10294000/10655280 | status 200
# Loaded 10295000/10655280 | status 200
# Loaded 10296000/10655280 | status 200
# Loaded 10297000/10655280 | status 200
# Loaded 10298000/10655280 | status 200
# Loaded 10299000/10655280 | status 200
# Loaded 10300000/10655280 | status 200
# Loaded 10301000/10655280 | status 200
# Loaded 10302000/10655280 | status 200
# Loaded 10303000/10655280 | status 200
# Loaded 10304000/10655280 | status 200
# Loaded 10305000/10655280 | status 200
# Loaded 10306000/10655280 | status 200
# Loaded 10307000/10655280 | status 200
# Loaded 10308000/10655280 | status 200
# Loaded 10309000/10655280 | status 200
# Loaded 10310000/10655280 | status 200
# Loaded 10311000/10655280 | status 200
# Loaded 10312000/10655280 | status 200
# Loaded 10313000/10655280 | status 200
# Loaded 10314000/10655280 | status 200
# Loaded 10315000/10655280 | status 200
# Loaded 10316000/10655280 | status 200
# Loaded 10317000/10655280 | status 200
# Loaded 10318000/10655280 | status 200
# Loaded 10319000/10655280 | status 200
# Loaded 10320000/10655280 | status 200
# Loaded 10321000/10655280 | status 200
# Loaded 10322000/10655280 | status 200
# Loaded 10323000/10655280 | status 200
# Loaded 10324000/10655280 | status 200
# Loaded 10325000/10655280 | status 200
# Loaded 10326000/10655280 | status 200
# Loaded 10327000/10655280 | status 200
# Loaded 10328000/10655280 | status 200
# Loaded 10329000/10655280 | status 200
# Loaded 10330000/10655280 | status 200
# Loaded 10331000/10655280 | status 200
# Loaded 10332000/10655280 | status 200
# Loaded 10333000/10655280 | status 200
# Loaded 10334000/10655280 | status 200
# Loaded 10335000/10655280 | status 200
# Loaded 10336000/10655280 | status 200
# Loaded 10337000/10655280 | status 200
# Loaded 10338000/10655280 | status 200
# Loaded 10339000/10655280 | status 200
# Loaded 10340000/10655280 | status 200
# Loaded 10341000/10655280 | status 200
# Loaded 10342000/10655280 | status 200
# Loaded 10343000/10655280 | status 200
# Loaded 10344000/10655280 | status 200
# Loaded 10345000/10655280 | status 200
# Loaded 10346000/10655280 | status 200
# Loaded 10347000/10655280 | status 200
# Loaded 10348000/10655280 | status 200
# Loaded 10349000/10655280 | status 200
# Loaded 10350000/10655280 | status 200
# Loaded 10351000/10655280 | status 200
# Loaded 10352000/10655280 | status 200
# Loaded 10353000/10655280 | status 200
# Loaded 10354000/10655280 | status 200
# Loaded 10355000/10655280 | status 200
# Loaded 10356000/10655280 | status 200
# Loaded 10357000/10655280 | status 200
# Loaded 10358000/10655280 | status 200
# Loaded 10359000/10655280 | status 200
# Loaded 10360000/10655280 | status 200
# Loaded 10361000/10655280 | status 200
# Loaded 10362000/10655280 | status 200
# Loaded 10363000/10655280 | status 200
# Loaded 10364000/10655280 | status 200
# Loaded 10365000/10655280 | status 200
# Loaded 10366000/10655280 | status 200
# Loaded 10367000/10655280 | status 200
# Loaded 10368000/10655280 | status 200
# Loaded 10369000/10655280 | status 200
# Loaded 10370000/10655280 | status 200
# Loaded 10371000/10655280 | status 200
# Loaded 10372000/10655280 | status 200
# Loaded 10373000/10655280 | status 200
# Loaded 10374000/10655280 | status 200
# Loaded 10375000/10655280 | status 200
# Loaded 10376000/10655280 | status 200
# Loaded 10377000/10655280 | status 200
# Loaded 10378000/10655280 | status 200
# Loaded 10379000/10655280 | status 200
# Loaded 10380000/10655280 | status 200
# Loaded 10381000/10655280 | status 200
# Loaded 10382000/10655280 | status 200
# Loaded 10383000/10655280 | status 200
# Loaded 10384000/10655280 | status 200
# Loaded 10385000/10655280 | status 200
# Loaded 10386000/10655280 | status 200
# Loaded 10387000/10655280 | status 200
# Loaded 10388000/10655280 | status 200
# Loaded 10389000/10655280 | status 200
# Loaded 10390000/10655280 | status 200
# Loaded 10391000/10655280 | status 200
# Loaded 10392000/10655280 | status 200
# Loaded 10393000/10655280 | status 200
# Loaded 10394000/10655280 | status 200
# Loaded 10395000/10655280 | status 200
# Loaded 10396000/10655280 | status 200
# Loaded 10397000/10655280 | status 200
# Loaded 10398000/10655280 | status 200
# Loaded 10399000/10655280 | status 200
# Loaded 10400000/10655280 | status 200
# Loaded 10401000/10655280 | status 200
# Loaded 10402000/10655280 | status 200
# Loaded 10403000/10655280 | status 200
# Loaded 10404000/10655280 | status 200
# Loaded 10405000/10655280 | status 200
# Loaded 10406000/10655280 | status 200
# Loaded 10407000/10655280 | status 200
# Loaded 10408000/10655280 | status 200
# Loaded 10409000/10655280 | status 200
# Loaded 10410000/10655280 | status 200
# Loaded 10411000/10655280 | status 200
# Loaded 10412000/10655280 | status 200
# Loaded 10413000/10655280 | status 200
# Loaded 10414000/10655280 | status 200
# Loaded 10415000/10655280 | status 200
# Loaded 10416000/10655280 | status 200
# Loaded 10417000/10655280 | status 200
# Loaded 10418000/10655280 | status 200
# Loaded 10419000/10655280 | status 200
# Loaded 10420000/10655280 | status 200
# Loaded 10421000/10655280 | status 200
# Loaded 10422000/10655280 | status 200
# Loaded 10423000/10655280 | status 200
# Loaded 10424000/10655280 | status 200
# Loaded 10425000/10655280 | status 200
# Loaded 10426000/10655280 | status 200
# Loaded 10427000/10655280 | status 200
# Loaded 10428000/10655280 | status 200
# Loaded 10429000/10655280 | status 200
# Loaded 10430000/10655280 | status 200
# Loaded 10431000/10655280 | status 200
# Loaded 10432000/10655280 | status 200
# Loaded 10433000/10655280 | status 200
# Loaded 10434000/10655280 | status 200
# Loaded 10435000/10655280 | status 200
# Loaded 10436000/10655280 | status 200
# Loaded 10437000/10655280 | status 200
# Loaded 10438000/10655280 | status 200
# Loaded 10439000/10655280 | status 200
# Loaded 10440000/10655280 | status 200
# Loaded 10441000/10655280 | status 200
# Loaded 10442000/10655280 | status 200
# Loaded 10443000/10655280 | status 200
# Loaded 10444000/10655280 | status 200
# Loaded 10445000/10655280 | status 200
# Loaded 10446000/10655280 | status 200
# Loaded 10447000/10655280 | status 200
# Loaded 10448000/10655280 | status 200
# Loaded 10449000/10655280 | status 200
# Loaded 10450000/10655280 | status 200
# Loaded 10451000/10655280 | status 200
# Loaded 10452000/10655280 | status 200
# Loaded 10453000/10655280 | status 200
# Loaded 10454000/10655280 | status 200
# Loaded 10455000/10655280 | status 200
# Loaded 10456000/10655280 | status 200
# Loaded 10457000/10655280 | status 200
# Loaded 10458000/10655280 | status 200
# Loaded 10459000/10655280 | status 200
# Loaded 10460000/10655280 | status 200
# Loaded 10461000/10655280 | status 200
# Loaded 10462000/10655280 | status 200
# Loaded 10463000/10655280 | status 200
# Loaded 10464000/10655280 | status 200
# Loaded 10465000/10655280 | status 200
# Loaded 10466000/10655280 | status 200
# Loaded 10467000/10655280 | status 200
# Loaded 10468000/10655280 | status 200
# Loaded 10469000/10655280 | status 200
# Loaded 10470000/10655280 | status 200
# Loaded 10471000/10655280 | status 200
# Loaded 10472000/10655280 | status 200
# Loaded 10473000/10655280 | status 200
# Loaded 10474000/10655280 | status 200
# Loaded 10475000/10655280 | status 200
# Loaded 10476000/10655280 | status 200
# Loaded 10477000/10655280 | status 200
# Loaded 10478000/10655280 | status 200
# Loaded 10479000/10655280 | status 200
# Loaded 10480000/10655280 | status 200
# Loaded 10481000/10655280 | status 200
# Loaded 10482000/10655280 | status 200
# Loaded 10483000/10655280 | status 200
# Loaded 10484000/10655280 | status 200
# Loaded 10485000/10655280 | status 200
# Loaded 10486000/10655280 | status 200
# Loaded 10487000/10655280 | status 200
# Loaded 10488000/10655280 | status 200
# Loaded 10489000/10655280 | status 200
# Loaded 10490000/10655280 | status 200
# Loaded 10491000/10655280 | status 200
# Loaded 10492000/10655280 | status 200
# Loaded 10493000/10655280 | status 200
# Loaded 10494000/10655280 | status 200
# Loaded 10495000/10655280 | status 200
# Loaded 10496000/10655280 | status 200
# Loaded 10497000/10655280 | status 200
# Loaded 10498000/10655280 | status 200
# Loaded 10499000/10655280 | status 200
# Loaded 10500000/10655280 | status 200
# Loaded 10501000/10655280 | status 200
# Loaded 10502000/10655280 | status 200
# Loaded 10503000/10655280 | status 200
# Loaded 10504000/10655280 | status 200
# Loaded 10505000/10655280 | status 200
# Loaded 10506000/10655280 | status 200
# Loaded 10507000/10655280 | status 200
# Loaded 10508000/10655280 | status 200
# Loaded 10509000/10655280 | status 200
# Loaded 10510000/10655280 | status 200
# Loaded 10511000/10655280 | status 200
# Loaded 10512000/10655280 | status 200
# Loaded 10513000/10655280 | status 200
# Loaded 10514000/10655280 | status 200
# Loaded 10515000/10655280 | status 200
# Loaded 10516000/10655280 | status 200
# Loaded 10517000/10655280 | status 200
# Loaded 10518000/10655280 | status 200
# Loaded 10519000/10655280 | status 200
# Loaded 10520000/10655280 | status 200
# Loaded 10521000/10655280 | status 200
# Loaded 10522000/10655280 | status 200
# Loaded 10523000/10655280 | status 200
# Loaded 10524000/10655280 | status 200
# Loaded 10525000/10655280 | status 200
# Loaded 10526000/10655280 | status 200
# Loaded 10527000/10655280 | status 200
# Loaded 10528000/10655280 | status 200
# Loaded 10529000/10655280 | status 200
# Loaded 10530000/10655280 | status 200
# Loaded 10531000/10655280 | status 200
# Loaded 10532000/10655280 | status 200
# Loaded 10533000/10655280 | status 200
# Loaded 10534000/10655280 | status 200
# Loaded 10535000/10655280 | status 200
# Loaded 10536000/10655280 | status 200
# Loaded 10537000/10655280 | status 200
# Loaded 10538000/10655280 | status 200
# Loaded 10539000/10655280 | status 200
# Loaded 10540000/10655280 | status 200
# Loaded 10541000/10655280 | status 200
# Loaded 10542000/10655280 | status 200
# Loaded 10543000/10655280 | status 200
# Loaded 10544000/10655280 | status 200
# Loaded 10545000/10655280 | status 200
# Loaded 10546000/10655280 | status 200
# Loaded 10547000/10655280 | status 200
# Loaded 10548000/10655280 | status 200
# Loaded 10549000/10655280 | status 200
# Loaded 10550000/10655280 | status 200
# Loaded 10551000/10655280 | status 200
# Loaded 10552000/10655280 | status 200
# Loaded 10553000/10655280 | status 200
# Loaded 10554000/10655280 | status 200
# Loaded 10555000/10655280 | status 200
# Loaded 10556000/10655280 | status 200
# Loaded 10557000/10655280 | status 200
# Loaded 10558000/10655280 | status 200
# Loaded 10559000/10655280 | status 200
# Loaded 10560000/10655280 | status 200
# Loaded 10561000/10655280 | status 200
# Loaded 10562000/10655280 | status 200
# Loaded 10563000/10655280 | status 200
# Loaded 10564000/10655280 | status 200
# Loaded 10565000/10655280 | status 200
# Loaded 10566000/10655280 | status 200
# Loaded 10567000/10655280 | status 200
# Loaded 10568000/10655280 | status 200
# Loaded 10569000/10655280 | status 200
# Loaded 10570000/10655280 | status 200
# Loaded 10571000/10655280 | status 200
# Loaded 10572000/10655280 | status 200
# Loaded 10573000/10655280 | status 200
# Loaded 10574000/10655280 | status 200
# Loaded 10575000/10655280 | status 200
# Loaded 10576000/10655280 | status 200
# Loaded 10577000/10655280 | status 200
# Loaded 10578000/10655280 | status 200
# Loaded 10579000/10655280 | status 200
# Loaded 10580000/10655280 | status 200
# Loaded 10581000/10655280 | status 200
# Loaded 10582000/10655280 | status 200
# Loaded 10583000/10655280 | status 200
# Loaded 10584000/10655280 | status 200
# Loaded 10585000/10655280 | status 200
# Loaded 10586000/10655280 | status 200
# Loaded 10587000/10655280 | status 200
# Loaded 10588000/10655280 | status 200
# Loaded 10589000/10655280 | status 200
# Loaded 10590000/10655280 | status 200
# Loaded 10591000/10655280 | status 200
# Loaded 10592000/10655280 | status 200
# Loaded 10593000/10655280 | status 200
# Loaded 10594000/10655280 | status 200
# Loaded 10595000/10655280 | status 200
# Loaded 10596000/10655280 | status 200
# Loaded 10597000/10655280 | status 200
# Loaded 10598000/10655280 | status 200
# Loaded 10599000/10655280 | status 200
# Loaded 10600000/10655280 | status 200
# Loaded 10601000/10655280 | status 200
# Loaded 10602000/10655280 | status 200
# Loaded 10603000/10655280 | status 200
# Loaded 10604000/10655280 | status 200
# Loaded 10605000/10655280 | status 200
# Loaded 10606000/10655280 | status 200
# Loaded 10607000/10655280 | status 200
# Loaded 10608000/10655280 | status 200
# Loaded 10609000/10655280 | status 200
# Loaded 10610000/10655280 | status 200
# Loaded 10611000/10655280 | status 200
# Loaded 10612000/10655280 | status 200
# Loaded 10613000/10655280 | status 200
# Loaded 10614000/10655280 | status 200
# Loaded 10615000/10655280 | status 200
# Loaded 10616000/10655280 | status 200
# Loaded 10617000/10655280 | status 200
# Loaded 10618000/10655280 | status 200
# Loaded 10619000/10655280 | status 200
# Loaded 10620000/10655280 | status 200
# Loaded 10621000/10655280 | status 200
# Loaded 10622000/10655280 | status 200
# Loaded 10623000/10655280 | status 200
# Loaded 10624000/10655280 | status 200
# Loaded 10625000/10655280 | status 200
# Loaded 10626000/10655280 | status 200
# Loaded 10627000/10655280 | status 200
# Loaded 10628000/10655280 | status 200
# Loaded 10629000/10655280 | status 200
# Loaded 10630000/10655280 | status 200
# Loaded 10631000/10655280 | status 200
# Loaded 10632000/10655280 | status 200
# Loaded 10633000/10655280 | status 200
# Loaded 10634000/10655280 | status 200
# Loaded 10635000/10655280 | status 200
# Loaded 10636000/10655280 | status 200
# Loaded 10637000/10655280 | status 200
# Loaded 10638000/10655280 | status 200
# Loaded 10639000/10655280 | status 200
# Loaded 10640000/10655280 | status 200
# Loaded 10641000/10655280 | status 200
# Loaded 10642000/10655280 | status 200
# Loaded 10643000/10655280 | status 200
# Loaded 10644000/10655280 | status 200
# Loaded 10645000/10655280 | status 200
# Loaded 10646000/10655280 | status 200
# Loaded 10647000/10655280 | status 200
# Loaded 10648000/10655280 | status 200
# Loaded 10649000/10655280 | status 200
# Loaded 10650000/10655280 | status 200
# Loaded 10651000/10655280 | status 200
# Loaded 10652000/10655280 | status 200
# Loaded 10653000/10655280 | status 200
# Loaded 10654000/10655280 | status 200
# Loaded 10655000/10655280 | status 200
# Loaded 10655280/10655280 | status 200

# %% [markdown]
# извлечь данные из opensearch

# %%
import requests
import pandas as pd

url = "https://127.0.0.1:9200/student_info/_search"
auth = ("admin","SamplePassword1!")

query = {
    "size": 10000,
    "query": {"match_all": {}}
}

response = requests.get(url, json=query, auth=auth, verify=False)

data = response.json()

rows = [doc["_source"] for doc in data["hits"]["hits"]]

df = pd.DataFrame(rows)

df.head(100)
# Out:
#    code_module code_presentation  id_student gender                region  \
# 0          AAA             2013J       11391      M   East Anglian Region
# 1          AAA             2013J       28400      F              Scotland
# 2          AAA             2013J       30268      F  North Western Region
# 3          AAA             2013J       31604      F     South East Region
# 4          AAA             2013J       32885      F  West Midlands Region
# ..         ...               ...         ...    ...                   ...
# 95         AAA             2013J      236284      M              Scotland
# 96         AAA             2013J      238007      M          South Region
# 97         AAA             2013J      240712      M         London Region
# 98         AAA             2013J      240884      M          South Region
# 99         AAA             2013J      241649      M   East Anglian Region
#
#               highest_education imd_band age_band  num_of_prev_attempts  \
# 0              HE Qualification  90-100%     55<=                     0
# 1              HE Qualification   20-30%    35-55                     0
# 2         A Level or Equivalent   30-40%    35-55                     0
# 3         A Level or Equivalent   50-60%    35-55                     0
# 4            Lower Than A Level   50-60%     0-35                     0
# ..                          ...      ...      ...                   ...
# 95  Post Graduate Qualification  90-100%     0-35                     0
# 96             HE Qualification  90-100%     55<=                     0
# 97             HE Qualification   80-90%     0-35                     0
# 98        A Level or Equivalent  90-100%     0-35                     0
# 99             HE Qualification  90-100%    35-55                     0
#
#     studied_credits disability final_result
# 0               240          N         Pass
# 1                60          N         Pass
# 2                60          Y    Withdrawn
# 3                60          N         Pass
# 4                60          N         Pass
# ..              ...        ...          ...
# 95               60          N         Pass
# 96               60          N         Pass
# 97               80          N         Pass
# 98              120          N         Pass
# 99               60          N         Pass
#
# [100 rows x 12 columns]
