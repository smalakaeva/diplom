# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Hi there!
#
# This is my first complete project, developed from beggining to end with all steps usually followed throughout the development of a machine learning and data science project. I originally developed this as part of an interview process and I'll be adapting the notebook I created for that to this environment. If you enjoy this work or if it was useful to you please upvote! Thanks!

# %% [markdown]
# The project started by deciding which problem we were going to solve. You could choose between making a clustering model in order to profile the students or make a forecasting model to predict whether a student would pass or fail their modules.
#
# I chose the prediction modeling problem and the data given was the same as given here. You can also go to https://analyse.kmi.open.ac.uk/open_dataset to find a more complete description of the data used here.

# %% [markdown]
# # The first step towards the solution is identifying which data sources will be relevant to the problem.
#
# Here we have a schema (from https://analyse.kmi.open.ac.uk/open_dataset) to illustrate the data structure of the set.
#
# ![schema.PNG](attachment:schema.PNG)
#
# As you can see, there are many different types of data involved, but since we want to make predictions about student performance it would be interesting to have:
#
# * A measurement of the students' commitment to the course throughout the period
#
# * A measurement of their performance during the period
#
# * Their final grades, as they are a huge part of the final grade composition
#
# Going to the indicated website, we can see that this info is contained under the following tables:
#
# - studentInfo
# - studentAssessment
# - assessments
# - studentVle
# - vle
#
# These tables will be our data sources for the model building process

# %%
studInfo=pd.read_csv("data_students/studentInfo.csv")
assessments=pd.read_csv("data_students/assessments.csv")
studAss=pd.read_csv("data_students/studentAssessment.csv")
studVle=pd.read_csv("data_students/studentVle.csv")
vle=pd.read_csv("data_students/vle.csv")

# %%
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB

# %%
studAss
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %% [markdown]
# # Part 1: Feature Engineering
#
# Here we will discuss how we used the given data in order to create features that made sense in order to build the model

# %% [markdown]
# # Assessments
#
# Результаты каждого экзамена являются хорошим показателем знаний студентов по курсу, и, поскольку они формируют оценку для итоговой оценки, интересно включить их в итоговую модель. Но, поскольку существует много разных курсов, каждый из которых имеет свою структуру, невозможно создать отдельную функцию для каждой оценки. Чтобы включить оценки, мы создадим 2 функции: одна из них - это итоговая оценка, полученная по баллам, и вес каждой оценки. Другой показатель - это проходной балл, созданный исходя из того, что студент должен набрать не менее 40% баллов по экзамену, чтобы сдать его, рассчитывая процент успешно сданных им оценок. Мы также отделим выпускные экзамены от других оценок, учитывая, что их статус и участие в итоговой оценке отличаются от других оценок.

# %%
exams=assessments[assessments["assessment_type"]=="Exam"]
others=assessments[assessments["assessment_type"]!="Exam"]
amounts=others.groupby(["code_module","code_presentation"]).count()["id_assessment"] 
amounts=amounts.reset_index()
amounts.head()
#Here we have the total amount of assessments by module
# Out:
#   code_module code_presentation  id_assessment
# 0         AAA             2013J              5
# 1         AAA             2014J              5
# 2         BBB             2013B             11
# 3         BBB             2013J             11
# 4         BBB             2014B             11

# %%
others
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 200         GGG             2014J          37442             CMA  229.0
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# 200     0.0
# 201     0.0
# 202     0.0
# 203     0.0
# 204     0.0
#
# [182 rows x 6 columns]

# %%
#Function to determine whether a student passed a given assessment
def pass_fail(grade):
    if grade>=40:
        return True
    else:
        return False
#Creating the stud_ass dataframe to join infos about the assessment weights and their respective grades
stud_ass=pd.merge(studAss,others,how="inner",on=["id_assessment"])
stud_ass["pass"]=stud_ass["score"].apply(pass_fail)
stud_ass["weighted_grade"]=stud_ass["score"]*stud_ass["weight"]/100

# %%
stud_ass
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score  \
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 168948          37443      527538             227          0   60.0
# 168949          37443      534672             229          0  100.0
# 168950          37443      546286             215          0   80.0
# 168951          37443      546724             230          0  100.0
# 168952          37443      558486             224          0   80.0
#
#        code_module code_presentation assessment_type   date  weight  pass  \
# 0              AAA             2013J             TMA   19.0    10.0  True
# 1              AAA             2013J             TMA   19.0    10.0  True
# 2              AAA             2013J             TMA   19.0    10.0  True
# 3              AAA             2013J             TMA   19.0    10.0  True
# 4              AAA             2013J             TMA   19.0    10.0  True
# ...            ...               ...             ...    ...     ...   ...
# 168948         GGG             2014J             CMA  229.0     0.0  True
# 168949         GGG             2014J             CMA  229.0     0.0  True
# 168950         GGG             2014J             CMA  229.0     0.0  True
# 168951         GGG             2014J             CMA  229.0     0.0  True
# 168952         GGG             2014J             CMA  229.0     0.0  True
#
#         weighted_grade
# 0                  7.8
# 1                  7.0
# 2                  7.2
# 3                  6.9
# 4                  7.9
# ...                ...
# 168948             0.0
# 168949             0.0
# 168950             0.0
# 168951             0.0
# 168952             0.0
#
# [168953 rows x 12 columns]

# %%
stud_ass
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score  \
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 168948          37443      527538             227          0   60.0
# 168949          37443      534672             229          0  100.0
# 168950          37443      546286             215          0   80.0
# 168951          37443      546724             230          0  100.0
# 168952          37443      558486             224          0   80.0
#
#        code_module code_presentation assessment_type   date  weight  pass  \
# 0              AAA             2013J             TMA   19.0    10.0  True
# 1              AAA             2013J             TMA   19.0    10.0  True
# 2              AAA             2013J             TMA   19.0    10.0  True
# 3              AAA             2013J             TMA   19.0    10.0  True
# 4              AAA             2013J             TMA   19.0    10.0  True
# ...            ...               ...             ...    ...     ...   ...
# 168948         GGG             2014J             CMA  229.0     0.0  True
# 168949         GGG             2014J             CMA  229.0     0.0  True
# 168950         GGG             2014J             CMA  229.0     0.0  True
# 168951         GGG             2014J             CMA  229.0     0.0  True
# 168952         GGG             2014J             CMA  229.0     0.0  True
#
#         weighted_grade
# 0                  7.8
# 1                  7.0
# 2                  7.2
# 3                  6.9
# 4                  7.9
# ...                ...
# 168948             0.0
# 168949             0.0
# 168950             0.0
# 168951             0.0
# 168952             0.0
#
# [168953 rows x 12 columns]

# %%
#Final assessment average per student per module
avg_grade=stud_ass.groupby(["id_student","code_module","code_presentation"]).sum()["weighted_grade"].reset_index()
avg_grade.head()
# Out:
#    id_student code_module code_presentation  weighted_grade
# 0        6516         AAA             2014J           63.50
# 1        8462         DDD             2013J           34.90
# 2        8462         DDD             2014J           43.00
# 3       11391         AAA             2013J           82.40
# 4       23629         BBB             2013B           16.69

# %%
#Pass rate per student per module
pass_rate=pd.merge((stud_ass[stud_ass["pass"]==True].groupby(["id_student","code_module","code_presentation"]).count()["pass"]).reset_index(),amounts,how="left",on=["code_module","code_presentation"])
pass_rate["pass_rate"]=pass_rate["pass"]/pass_rate["id_assessment"]
pass_rate.drop(["pass","id_assessment"], axis=1,inplace=True)
pass_rate.head()
# Out:
#    id_student code_module code_presentation  pass_rate
# 0        6516         AAA             2014J   1.000000
# 1        8462         DDD             2013J   0.500000
# 2        8462         DDD             2014J   0.666667
# 3       11391         AAA             2013J   1.000000
# 4       23629         BBB             2013B   0.363636

# %%
#Final exam scores
stud_exams=pd.merge(studAss,exams,how="inner",on=["id_assessment"])
stud_exams["exam_score"]=stud_exams["score"]
stud_exams.drop(["id_assessment","date_submitted","is_banked", "score","assessment_type","date","weight"],axis=1,inplace=True)
stud_exams.head()
# Out:
#    id_student code_module code_presentation  exam_score
# 0      558914         CCC             2014B        32.0
# 1      559706         CCC             2014B        78.0
# 2      559770         CCC             2014B        54.0
# 3      560114         CCC             2014B        64.0
# 4      560311         CCC             2014B       100.0

# %% [markdown]
# # VLE
#
# Наборы данных, относящиеся к VLE (виртуальной учебной среде), содержат информацию о взаимодействии учащихся с контентом, доступным для ознакомления в течение всего периода обучения. Исходя из этих данных, мы можем сделать вывод о том, насколько хорошо студент разбирался в своих предметах, тщательно ли он их изучал и как использовал контент.

# %%
vle
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]

# %%
vle[~vle["week_from"].isna()]
#Только в 1121 из 6364 заявок указана контрольная неделя для материалов (неделя, в течение которой они будут использоваться в курсе).
#Учитывая это, создание показателя для отслеживания приверженности учебе становится непрактичным
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 113    546732         AAA             2013J     oucontent        2.0      2.0
# 198    546719         AAA             2013J     oucontent        1.0      1.0
# 210    546681         AAA             2013J     oucontent        1.0      1.0
# 264    877040         AAA             2014J     oucontent        2.0      2.0
# 323    877045         AAA             2014J     oucontent        1.0      1.0
# ...       ...         ...               ...           ...        ...      ...
# 6243   798728         GGG             2014B      resource        1.0      1.0
# 6266   897051         GGG             2014J      resource        2.0      2.0
# 6285   897121         GGG             2014J      resource        1.0      1.0
# 6304   897050         GGG             2014J      resource        1.0      1.0
# 6335   897052         GGG             2014J      resource        3.0      3.0
#
# [1121 rows x 6 columns]

# %%
studVle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %% [markdown]
# Обычно date — это временная метка (дни относительно начала курса), и усреднение дат имеет смысл только для анализа паттернов поведения.
# Средняя дата посещения (date) — показывает, когда в среднем студент посещал этот ресурс (отрицательное = до начала, положительное = после начала)

# %%
#Здесь мы можем отслеживать среднее время, затраченное студентом после начала курса на использование материалов
#, и среднее количество кликов по каждому материалу

avg_per_site=studVle.groupby(["id_student","id_site","code_module","code_presentation"]).mean().reset_index()
avg_per_site.head()
# Out:
#    id_student  id_site code_module code_presentation        date  sum_click
# 0        6516   877011         AAA             2014J  210.333333   3.833333
# 1        6516   877012         AAA             2014J   90.833333   2.310606
# 2        6516   877015         AAA             2014J  113.461538   2.000000
# 3        6516   877023         AAA             2014J  122.666667   2.000000
# 4        6516   877025         AAA             2014J   41.142857   4.333333

# %%
#General average per student per module
avg_per_student=avg_per_site.groupby(["id_student","code_module","code_presentation"]).mean()[["date","sum_click"]].reset_index()
avg_per_student.head()
# Out:
#    id_student code_module code_presentation        date  sum_click
# 0        6516         AAA             2014J  105.292573   5.816135
# 1        8462         DDD             2013J   38.794704   1.734524
# 2        8462         DDD             2014J   10.000000   3.000000
# 3       11391         AAA             2013J  111.739069   4.231515
# 4       23629         BBB             2013B   33.409632   2.817316

# %% [markdown]
# # StudentInfo
#
# Таблица StudentInfo содержит различную информацию о студентах, но для этого анализа важны следующие данные::
#
# * Количество раз, когда студент уже пытался завершить модуль
# * Конечный результат студентов
#
# Последняя переменная является нашей переменной интереса при построении нашей модели прогнозирования

# %%
#Removing the cases where the student has withdrawn their registration to the module
studInfo=studInfo[studInfo["final_result"]!="Withdrawn"]
studInfo=studInfo[["code_module","code_presentation","id_student","num_of_prev_attempts","final_result"]]
studInfo.head()
# Out:
#   code_module code_presentation  id_student  num_of_prev_attempts final_result
# 0         AAA             2013J       11391                     0         Pass
# 1         AAA             2013J       28400                     0         Pass
# 3         AAA             2013J       31604                     0         Pass
# 4         AAA             2013J       32885                     0         Pass
# 5         AAA             2013J       38053                     0         Pass

# %% [markdown]
# # Compiling all relevant tables

# %%
df_1=pd.merge(avg_grade,pass_rate,how="inner",on=["id_student","code_module","code_presentation"])
assessment_info=pd.merge(df_1, stud_exams, how="inner", on=["id_student","code_module","code_presentation"])
assessment_info.head()
# Out:
#    id_student code_module code_presentation  weighted_grade  pass_rate  \
# 0       23698         CCC             2014J           69.97   1.000000
# 1       24213         DDD             2014B           78.40   1.000000
# 2       27116         CCC             2014J           92.02   1.000000
# 3       28046         DDD             2013J           49.90   0.833333
# 4       28787         CCC             2014J           11.98   0.375000
#
#    exam_score
# 0        80.0
# 1        58.0
# 2        96.0
# 3        40.0
# 4        44.0

# %%
df_2=pd.merge(studInfo,assessment_info,how="inner",on=["id_student","code_module","code_presentation"])
final_df=pd.merge(df_2,avg_per_student,how="inner", on=["id_student","code_module","code_presentation"])
final_df.drop(["id_student","code_module","code_presentation"],axis=1,inplace=True)
final_df.head()
#The final dataframe only has information relevant to the problem
# Out:
#    num_of_prev_attempts final_result  weighted_grade  pass_rate  exam_score  \
# 0                     0  Distinction           89.65      1.000        94.0
# 1                     0         Pass           84.58      1.000        76.0
# 2                     0         Pass           51.44      0.625        66.0
# 3                     0         Pass           75.13      1.000        50.0
# 4                     0  Distinction           93.22      1.000        98.0
#
#          date  sum_click
# 0  103.457907   2.706754
# 1   87.617265   1.539047
# 2   49.181286   1.562619
# 3  118.698642   2.189217
# 4   75.791987   2.100617

# %% [markdown]
# # Part 2: EDA
#
# We start the exploratory data analysis by checking the dataframe integrity

# %%
final_df.describe()
# Out:
#        num_of_prev_attempts  weighted_grade    pass_rate   exam_score  \
# count           4950.000000     4950.000000  4950.000000  4950.000000
# mean               0.118586       66.280909     0.868616    65.604444
# std                0.395313       21.221975     0.182934    20.564815
# min                0.000000        1.120000     0.125000     0.000000
# 25%                0.000000       51.512500     0.769231    51.000000
# 50%                0.000000       69.760000     1.000000    67.000000
# 75%                0.000000       83.622500     1.000000    82.000000
# max                5.000000      100.000000     1.000000   100.000000
#
#               date    sum_click
# count  4950.000000  4950.000000
# mean    101.047138     2.016114
# std      24.917830     0.722249
# min      17.566546     1.000000
# 25%      84.681549     1.545160
# 50%      99.934672     1.802246
# 75%     116.635412     2.279943
# max     237.035714    13.134308

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4950 entries, 0 to 4949
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   num_of_prev_attempts  4950 non-null   int64
#  1   final_result          4950 non-null   object
#  2   weighted_grade        4950 non-null   float64
#  3   pass_rate             4950 non-null   float64
#  4   exam_score            4950 non-null   float64
#  5   date                  4950 non-null   float64
#  6   sum_click             4950 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 270.8+ KB

# %% [markdown]
# # Тот факт, что целевой признак является категориальным, не позволяет нам включить его в корреляционную матрицу, но мы можем видеть тенденцию корреляции между оценочными признаками (*weighted_grade, pass_rate* и *exam_score*).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(final_df.corr(),annot=True)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 4
#       2 import seaborn as sns
#       3 plt.figure(figsize=(8,6))
# ----> 4 sns.heatmap(final_df.corr(),annot=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Distinction'

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=final_df, x="final_result")
# Out:
# <Axes: xlabel='final_result', ylabel='count'>

# %% [markdown]
# # With a "Pass" count much higher than the other labels, we must pay attention to the performance metrics fot the models and analyse the least represented cases more closely

# %%
sns.pairplot(final_df)

# %% [markdown]
# # On the pairplot we can detect two outliers: One with an average click number way above average and another one with a sole occurrence of an amount of previous attempts. In order to keep our data as consistent as possible, these cases will be removed

# %%
final_df[final_df["sum_click"]>10]
# Out:
#     num_of_prev_attempts final_result  weighted_grade  pass_rate  exam_score  \
# 71                     0         Pass           70.37      0.875        74.0
#
#           date  sum_click
# 71  137.702513  13.134308

# %%
final_df[final_df["num_of_prev_attempts"]>4]
# Out:
#       num_of_prev_attempts final_result  weighted_grade  pass_rate  \
# 4908                     5         Pass            87.3        1.0
#
#       exam_score        date  sum_click
# 4908        76.0  127.634406   1.558457

# %%
final_df=final_df[final_df["sum_click"]<=10]
final_df=final_df[final_df["num_of_prev_attempts"]<=4]
final_df.head()
# Out:
#    num_of_prev_attempts final_result  weighted_grade  pass_rate  exam_score  \
# 0                     0  Distinction           89.65      1.000        94.0
# 1                     0         Pass           84.58      1.000        76.0
# 2                     0         Pass           51.44      0.625        66.0
# 3                     0         Pass           75.13      1.000        50.0
# 4                     0  Distinction           93.22      1.000        98.0
#
#          date  sum_click
# 0  103.457907   2.706754
# 1   87.617265   1.539047
# 2   49.181286   1.562619
# 3  118.698642   2.189217
# 4   75.791987   2.100617

# %% [markdown]
# # Part 3: Modeling
#
# For the modeling step we will use the following techniques and models:
#
# * Cross validation paired with classification reports and confusion matrices to evaluate model performance
# * Logistic Regression
# * Linear Discriminant Analysis
# * Random Forest
# * Neural Network Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping

# %%
X=final_df.drop("final_result", axis=1)
y=final_df["final_result"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Given the high correlation between *weighted_grade* and *pass_rate* the models will be fit to 3 types of inputs: One with both features and one with each one of them removed from the dataset

# %%
#1 contains both, 2 just pass_rate e 3 just weighted_grade
X1_test=X_test
X1_train=X_train
X2_test=X_test.drop("weighted_grade",axis=1)
X2_train=X_train.drop("weighted_grade",axis=1)
X3_test=X_test.drop("pass_rate",axis=1)
X3_train=X_train.drop("pass_rate",axis=1)

# %%
scaler1=MinMaxScaler()
scaler2=MinMaxScaler()
scaler3=MinMaxScaler()

# %%
X1_train=scaler1.fit_transform(X1_train)
X1_test=scaler1.transform(X1_test)
X2_train=scaler2.fit_transform(X2_train)
X2_test=scaler2.transform(X2_test)
X3_train=scaler3.fit_transform(X3_train)
X3_test=scaler3.transform(X3_test)

# %% [markdown]
# # Model 1: Logistic Regression

# %% [markdown]
# $$
# \text{precision} = \frac{TP}{TP + FP}
# $$
#
# $$
# \text{recall} = \frac{TP}{TP + FN}
# $$
#
# $$
# \text{F1-measure} = \frac{2 * \text{precision} * \text{recall}}{\text{precision} + \text{recall}} = \frac{2 * TP}{2 * TP + FP + FN}
# $$

# %%
lr1=LogisticRegression(max_iter=10000)
lr1.fit(X1_train,y_train)
result_lr1=lr1.predict(X1_test)
print(confusion_matrix(y_test,result_lr1))
print("\n")
print(classification_report(y_test,result_lr1))
# Out:
# [[189   0  58]
#  [  0 138  64]
#  [ 36  23 977]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.84      0.77      0.80       247
#         Fail       0.86      0.68      0.76       202
#         Pass       0.89      0.94      0.92      1036
#
#     accuracy                           0.88      1485
#    macro avg       0.86      0.80      0.83      1485
# weighted avg       0.88      0.88      0.88      1485

# %%
lr2=LogisticRegression(max_iter=10000)
lr2.fit(X2_train,y_train)
result_lr2=lr2.predict(X2_test)
print(confusion_matrix(y_test,result_lr2))
print("\n")
print(classification_report(y_test,result_lr2))
# Out:
# [[186   0  61]
#  [  0 136  66]
#  [ 37  22 977]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.83      0.75      0.79       247
#         Fail       0.86      0.67      0.76       202
#         Pass       0.88      0.94      0.91      1036
#
#     accuracy                           0.87      1485
#    macro avg       0.86      0.79      0.82      1485
# weighted avg       0.87      0.87      0.87      1485

# %%
lr3=LogisticRegression(max_iter=10000)
lr3.fit(X3_train,y_train)
result_lr3=lr3.predict(X3_test)
print(confusion_matrix(y_test,result_lr3))
print("\n")
print(classification_report(y_test,result_lr3))
# Out:
# [[187   0  60]
#  [  0 138  64]
#  [ 37  25 974]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.83      0.76      0.79       247
#         Fail       0.85      0.68      0.76       202
#         Pass       0.89      0.94      0.91      1036
#
#     accuracy                           0.87      1485
#    macro avg       0.86      0.79      0.82      1485
# weighted avg       0.87      0.87      0.87      1485

# %% [markdown]
# # Model 2: LDA

# %%
lda1=LinearDiscriminantAnalysis()
lda1.fit_transform(X1_train,y_train)
result_lda1=lda1.predict(X1_test)
print(confusion_matrix(y_test,result_lda1))
print("\n")
print(classification_report(y_test,result_lda1))
# Out:
# [[211   0  36]
#  [  0 156  46]
#  [ 59  46 931]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.78      0.85      0.82       247
#         Fail       0.77      0.77      0.77       202
#         Pass       0.92      0.90      0.91      1036
#
#     accuracy                           0.87      1485
#    macro avg       0.82      0.84      0.83      1485
# weighted avg       0.88      0.87      0.87      1485

# %%
lda2=LinearDiscriminantAnalysis()
lda2.fit_transform(X2_train,y_train)
result_lda2=lda2.predict(X2_test)
print(confusion_matrix(y_test,result_lda2))
print("\n")
print(classification_report(y_test,result_lda2))
# Out:
# [[218   0  29]
#  [  0 161  41]
#  [ 60  45 931]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.78      0.88      0.83       247
#         Fail       0.78      0.80      0.79       202
#         Pass       0.93      0.90      0.91      1036
#
#     accuracy                           0.88      1485
#    macro avg       0.83      0.86      0.84      1485
# weighted avg       0.89      0.88      0.88      1485

# %%
lda3=LinearDiscriminantAnalysis()
lda3.fit_transform(X3_train,y_train)
result_lda3=lda3.predict(X3_test)
print(confusion_matrix(y_test,result_lda3))
print("\n")
print(classification_report(y_test,result_lda3))
# Out:
# [[212   0  35]
#  [  0 162  40]
#  [ 58  47 931]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.79      0.86      0.82       247
#         Fail       0.78      0.80      0.79       202
#         Pass       0.93      0.90      0.91      1036
#
#     accuracy                           0.88      1485
#    macro avg       0.83      0.85      0.84      1485
# weighted avg       0.88      0.88      0.88      1485

# %% [markdown]
# # Model 3: Random Forest

# %%
rf1=RandomForestClassifier(n_estimators=300)
rf1.fit(X1_train,y_train)
result_rf1=rf1.predict(X1_test)
print(confusion_matrix(y_test,result_rf1))
print("\n")
print(classification_report(y_test,result_rf1))
# Out:
# [[209   0  38]
#  [  0 156  46]
#  [ 34  22 980]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.86      0.85      0.85       247
#         Fail       0.88      0.77      0.82       202
#         Pass       0.92      0.95      0.93      1036
#
#     accuracy                           0.91      1485
#    macro avg       0.89      0.85      0.87      1485
# weighted avg       0.90      0.91      0.90      1485

# %%
rf2=RandomForestClassifier(n_estimators=300)
rf2.fit(X2_train,y_train)
result_rf2=rf2.predict(X2_test)
print(confusion_matrix(y_test,result_rf2))
print("\n")
print(classification_report(y_test,result_rf2))
# Out:
# [[203   0  44]
#  [  0 154  48]
#  [ 51  24 961]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.80      0.82      0.81       247
#         Fail       0.87      0.76      0.81       202
#         Pass       0.91      0.93      0.92      1036
#
#     accuracy                           0.89      1485
#    macro avg       0.86      0.84      0.85      1485
# weighted avg       0.89      0.89      0.89      1485

# %%
rf3=RandomForestClassifier(n_estimators=300)
rf3.fit(X3_train,y_train)
result_rf3=rf3.predict(X3_test)
print(confusion_matrix(y_test,result_rf3))
print("\n")
print(classification_report(y_test,result_rf3))
# Out:
# [[209   0  38]
#  [  0 153  49]
#  [ 34  23 979]]
#
#
#               precision    recall  f1-score   support
#
#  Distinction       0.86      0.85      0.85       247
#         Fail       0.87      0.76      0.81       202
#         Pass       0.92      0.94      0.93      1036
#
#     accuracy                           0.90      1485
#    macro avg       0.88      0.85      0.86      1485
# weighted avg       0.90      0.90      0.90      1485

# %% [markdown]
# # Model 4: Neural Network Classifier

# %%
model1=Sequential()

model1.add(Dense(6, activation="relu"))
model1.add(Dropout(0.5))
model1.add(Dense(3, activation="relu"))
model1.add(Dense(1, activation="sigmoid"))

model1.compile(loss="binary_crossentropy", optimizer="adam")

# %%
model2=Sequential()

model2.add(Dense(5, activation="relu"))
model2.add(Dropout(0.5))
model2.add(Dense(3, activation="relu"))
model2.add(Dense(1, activation="sigmoid"))

model2.compile(loss="binary_crossentropy", optimizer="adam")

# %%
model3=Sequential()

model3.add(Dense(5, activation="relu"))
model3.add(Dropout(0.5))
model3.add(Dense(3, activation="relu"))
model3.add(Dense(1, activation="sigmoid"))

model3.compile(loss="binary_crossentropy", optimizer="adam")

# %%
#For the neural network training, the outputs needed to be codified, and in order to avoid the ordinalization
#of the classes I chose to classify the distintion cases toghether with thw pass cases
def categories(cat):
    if cat=="Fail":
        return 0
    if cat=="Pass":
        return 1
    if cat=="Distinction":
        return 1
    
y_test=list(map(categories,y_test))
y_train=list(map(categories,y_train))

# %%
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)
early_stop=EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=25)

# %%
model1.fit(x=X1_train, y=y_train, epochs=2000, validation_data=(X1_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/2000
# 109/109 [==============================] - 0s 3ms/step - loss: 0.6830 - val_loss: 0.6568
# Epoch 2/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.6402 - val_loss: 0.6240
# Epoch 3/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.6087 - val_loss: 0.5944
# Epoch 4/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5799 - val_loss: 0.5673
# Epoch 5/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5538 - val_loss: 0.5428
# Epoch 6/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5299 - val_loss: 0.5198
# Epoch 7/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5083 - val_loss: 0.4987
# Epoch 8/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4897 - val_loss: 0.4806
# Epoch 9/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4705 - val_loss: 0.4630
# Epoch 10/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4555 - val_loss: 0.4469
# Epoch 11/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4380 - val_loss: 0.4310
# Epoch 12/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4265 - val_loss: 0.4193
# Epoch 13/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4139 - val_loss: 0.4048
# Epoch 14/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4053 - val_loss: 0.3936
# Epoch 15/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3924 - val_loss: 0.3830
# Epoch 16/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3843 - val_loss: 0.3724
# Epoch 17/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3752 - val_loss: 0.3614
# Epoch 18/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3657 - val_loss: 0.3515
# Epoch 19/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3546 - val_loss: 0.3414
# Epoch 20/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3463 - val_loss: 0.3305
# Epoch 21/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3339 - val_loss: 0.3235
# Epoch 22/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3345 - val_loss: 0.3143
# Epoch 23/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3241 - val_loss: 0.3091
# Epoch 24/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3259 - val_loss: 0.2979
# Epoch 25/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3134 - val_loss: 0.2926
# Epoch 26/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3143 - val_loss: 0.2908
# Epoch 27/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3042 - val_loss: 0.2880
# Epoch 28/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3025 - val_loss: 0.2771
# Epoch 29/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3026 - val_loss: 0.2703
# Epoch 30/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2908 - val_loss: 0.2659
# Epoch 31/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2890 - val_loss: 0.2637
# Epoch 32/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2871 - val_loss: 0.2555
# Epoch 33/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2677 - val_loss: 0.2501
# Epoch 34/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2707 - val_loss: 0.2448
# Epoch 35/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2804 - val_loss: 0.2479
# Epoch 36/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2640 - val_loss: 0.2403
# Epoch 37/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2667 - val_loss: 0.2383
# Epoch 38/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2577 - val_loss: 0.2307
# Epoch 39/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2532 - val_loss: 0.2315
# Epoch 40/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2530 - val_loss: 0.2286
# Epoch 41/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2618 - val_loss: 0.2298
# Epoch 42/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2474 - val_loss: 0.2182
# Epoch 43/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2469 - val_loss: 0.2149
# Epoch 44/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2419 - val_loss: 0.2103
# Epoch 45/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2317 - val_loss: 0.2090
# Epoch 46/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2356 - val_loss: 0.2104
# Epoch 47/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2377 - val_loss: 0.2066
# Epoch 48/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2294 - val_loss: 0.2079
# Epoch 49/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2350 - val_loss: 0.2024
# Epoch 50/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2285 - val_loss: 0.1979
# Epoch 51/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2174 - val_loss: 0.2004
# Epoch 52/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2255 - val_loss: 0.1966
# Epoch 53/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2224 - val_loss: 0.1923
# Epoch 54/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2168 - val_loss: 0.1923
# Epoch 55/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2111 - val_loss: 0.1936
# Epoch 56/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2149 - val_loss: 0.1911
# Epoch 57/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2209 - val_loss: 0.1919
# Epoch 58/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2185 - val_loss: 0.1887
# Epoch 59/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2102 - val_loss: 0.1832
# Epoch 60/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2069 - val_loss: 0.1836
# Epoch 61/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2066 - val_loss: 0.1834
# Epoch 62/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2079 - val_loss: 0.1839
# Epoch 63/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2060 - val_loss: 0.1869
# Epoch 64/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2071 - val_loss: 0.1815
# Epoch 65/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2091 - val_loss: 0.1801
# Epoch 66/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2032 - val_loss: 0.1803
# Epoch 67/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2079 - val_loss: 0.1796
# Epoch 68/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2025 - val_loss: 0.1790
# Epoch 69/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2120 - val_loss: 0.1834
# Epoch 70/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2073 - val_loss: 0.1783
# Epoch 71/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2111 - val_loss: 0.1830
# Epoch 72/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2040 - val_loss: 0.1755
# Epoch 73/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2025 - val_loss: 0.1767
# Epoch 74/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2010 - val_loss: 0.1772
# Epoch 75/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1983 - val_loss: 0.1820
# Epoch 76/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2017 - val_loss: 0.1763
# Epoch 77/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2078 - val_loss: 0.1790
# Epoch 78/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1965 - val_loss: 0.1756
# Epoch 79/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1969 - val_loss: 0.1759
# Epoch 80/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2049 - val_loss: 0.1792
# Epoch 81/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1939 - val_loss: 0.1823
# Epoch 82/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2085 - val_loss: 0.1814
# Epoch 83/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2011 - val_loss: 0.1783
# Epoch 84/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1987 - val_loss: 0.1815
# Epoch 85/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2015 - val_loss: 0.1759
# Epoch 86/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1966 - val_loss: 0.1783
# Epoch 87/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2022 - val_loss: 0.1799
# Epoch 88/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2003 - val_loss: 0.1776
# Epoch 89/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1976 - val_loss: 0.1736
# Epoch 90/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2037 - val_loss: 0.1728
# Epoch 91/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1991 - val_loss: 0.1755
# Epoch 92/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1955 - val_loss: 0.1764
# Epoch 93/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1957 - val_loss: 0.1722
# Epoch 94/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1979 - val_loss: 0.1732
# Epoch 95/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1915 - val_loss: 0.1833
# Epoch 96/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1984 - val_loss: 0.1740
# Epoch 97/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1919 - val_loss: 0.1718
# Epoch 98/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2001 - val_loss: 0.1768
# Epoch 99/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1969 - val_loss: 0.1791
# Epoch 100/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1949 - val_loss: 0.1785
# Epoch 101/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1949 - val_loss: 0.1773
# Epoch 102/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1969 - val_loss: 0.1788
# Epoch 103/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2033 - val_loss: 0.1713
# Epoch 104/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1901 - val_loss: 0.1736
# Epoch 105/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1897 - val_loss: 0.1744
# Epoch 106/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1967 - val_loss: 0.1782
# Epoch 107/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1894 - val_loss: 0.1771
# Epoch 108/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1934 - val_loss: 0.1750
# Epoch 109/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1901 - val_loss: 0.1700
# Epoch 110/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1973 - val_loss: 0.1789
# Epoch 111/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2005 - val_loss: 0.1749
# Epoch 112/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1957 - val_loss: 0.1693
# Epoch 113/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1875 - val_loss: 0.1702
# Epoch 114/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1873 - val_loss: 0.1826
# Epoch 115/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1974 - val_loss: 0.1743
# Epoch 116/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1955 - val_loss: 0.1711
# Epoch 117/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1935 - val_loss: 0.1644
# Epoch 118/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1960 - val_loss: 0.1744
# Epoch 119/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1883 - val_loss: 0.1743
# Epoch 120/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1957 - val_loss: 0.1768
# Epoch 121/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1887 - val_loss: 0.1671
# Epoch 122/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1949 - val_loss: 0.1668
# Epoch 123/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1975 - val_loss: 0.1713
# Epoch 124/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1866 - val_loss: 0.1709
# Epoch 125/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1954 - val_loss: 0.1755
# Epoch 126/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1886 - val_loss: 0.1718
# Epoch 127/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1916 - val_loss: 0.1772
# Epoch 128/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1943 - val_loss: 0.1622
# Epoch 129/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1932 - val_loss: 0.1699
# Epoch 130/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1914 - val_loss: 0.1696
# Epoch 131/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1923 - val_loss: 0.1667
# Epoch 132/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1979 - val_loss: 0.1664
# Epoch 133/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1854 - val_loss: 0.1616
# Epoch 134/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1881 - val_loss: 0.1687
# Epoch 135/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1845 - val_loss: 0.1687
# Epoch 136/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1867 - val_loss: 0.1699
# Epoch 137/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1921 - val_loss: 0.1709
# Epoch 138/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1978 - val_loss: 0.1671
# Epoch 139/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1914 - val_loss: 0.1688
# Epoch 140/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1915 - val_loss: 0.1676
# Epoch 141/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1921 - val_loss: 0.1678
# Epoch 142/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1858 - val_loss: 0.1658
# Epoch 143/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1911 - val_loss: 0.1670
# Epoch 144/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1886 - val_loss: 0.1694
# Epoch 145/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1862 - val_loss: 0.1572
# Epoch 146/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1908 - val_loss: 0.1568
# Epoch 147/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1848 - val_loss: 0.1608
# Epoch 148/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1895 - val_loss: 0.1624
# Epoch 149/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1792 - val_loss: 0.1607
# Epoch 150/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1917 - val_loss: 0.1674
# Epoch 151/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1913 - val_loss: 0.1645
# Epoch 152/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1859 - val_loss: 0.1555
# Epoch 153/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1891 - val_loss: 0.1656
# Epoch 154/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1868 - val_loss: 0.1579
# Epoch 155/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1871 - val_loss: 0.1640
# Epoch 156/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1794 - val_loss: 0.1637
# Epoch 157/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1888 - val_loss: 0.1744
# Epoch 158/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1867 - val_loss: 0.1543
# Epoch 159/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1908 - val_loss: 0.1586
# Epoch 160/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1843 - val_loss: 0.1602
# Epoch 161/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1930 - val_loss: 0.1614
# Epoch 162/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1877 - val_loss: 0.1577
# Epoch 163/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1874 - val_loss: 0.1600
# Epoch 164/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1837 - val_loss: 0.1635
# Epoch 165/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1871 - val_loss: 0.1661
# Epoch 166/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1833 - val_loss: 0.1613
# Epoch 167/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1859 - val_loss: 0.1598
# Epoch 168/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1857 - val_loss: 0.1575
# Epoch 169/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1841 - val_loss: 0.1565
# Epoch 170/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1884 - val_loss: 0.1652
# Epoch 171/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1861 - val_loss: 0.1586
# Epoch 172/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1864 - val_loss: 0.1596
# Epoch 173/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1895 - val_loss: 0.1584
# Epoch 174/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1881 - val_loss: 0.1628
# Epoch 175/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1767 - val_loss: 0.1603
# Epoch 176/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1783 - val_loss: 0.1584
# Epoch 177/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1848 - val_loss: 0.1598
# Epoch 178/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1948 - val_loss: 0.1557
# Epoch 179/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1844 - val_loss: 0.1596
# Epoch 180/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1868 - val_loss: 0.1562
# Epoch 181/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1865 - val_loss: 0.1558
# Epoch 182/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.1890 - val_loss: 0.1572
# Epoch 183/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.1823 - val_loss: 0.1607
# Epoch 00183: early stopping

# %%
losses=pd.DataFrame(model1.history.history)
losses.plot()

# %%
predictions=model1.predict_classes(X1_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[ 106   96]
#  [   9 1274]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.52      0.67       202
#            1       0.93      0.99      0.96      1283
#
#     accuracy                           0.93      1485
#    macro avg       0.93      0.76      0.81      1485
# weighted avg       0.93      0.93      0.92      1485

# %%
model2.fit(x=X2_train, y=y_train, epochs=2000, validation_data=(X2_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.7346 - val_loss: 0.6699
# Epoch 2/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.6454 - val_loss: 0.6200
# Epoch 3/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5944 - val_loss: 0.5685
# Epoch 4/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5331 - val_loss: 0.4852
# Epoch 5/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4620 - val_loss: 0.4087
# Epoch 6/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4238 - val_loss: 0.3804
# Epoch 7/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4115 - val_loss: 0.3725
# Epoch 8/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4039 - val_loss: 0.3706
# Epoch 9/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3969 - val_loss: 0.3689
# Epoch 10/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3965 - val_loss: 0.3668
# Epoch 11/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3935 - val_loss: 0.3654
# Epoch 12/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3926 - val_loss: 0.3629
# Epoch 13/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3867 - val_loss: 0.3613
# Epoch 14/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3858 - val_loss: 0.3596
# Epoch 15/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3814 - val_loss: 0.3569
# Epoch 16/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3814 - val_loss: 0.3554
# Epoch 17/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3699 - val_loss: 0.3524
# Epoch 18/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3668 - val_loss: 0.3491
# Epoch 19/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3595 - val_loss: 0.3451
# Epoch 20/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3614 - val_loss: 0.3418
# Epoch 21/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.3559 - val_loss: 0.3379
# Epoch 22/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3515 - val_loss: 0.3337
# Epoch 23/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3477 - val_loss: 0.3286
# Epoch 24/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3405 - val_loss: 0.3225
# Epoch 25/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3372 - val_loss: 0.3176
# Epoch 26/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.3323 - val_loss: 0.3123
# Epoch 27/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.3255 - val_loss: 0.3059
# Epoch 28/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3247 - val_loss: 0.3007
# Epoch 29/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3172 - val_loss: 0.2948
# Epoch 30/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3195 - val_loss: 0.2899
# Epoch 31/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3128 - val_loss: 0.2864
# Epoch 32/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3088 - val_loss: 0.2809
# Epoch 33/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3072 - val_loss: 0.2760
# Epoch 34/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3047 - val_loss: 0.2723
# Epoch 35/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2993 - val_loss: 0.2663
# Epoch 36/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3046 - val_loss: 0.2633
# Epoch 37/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2970 - val_loss: 0.2591
# Epoch 38/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2982 - val_loss: 0.2567
# Epoch 39/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2951 - val_loss: 0.2538
# Epoch 40/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2985 - val_loss: 0.2506
# Epoch 41/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2937 - val_loss: 0.2479
# Epoch 42/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2905 - val_loss: 0.2447
# Epoch 43/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2959 - val_loss: 0.2438
# Epoch 44/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2919 - val_loss: 0.2418
# Epoch 45/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2887 - val_loss: 0.2391
# Epoch 46/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2895 - val_loss: 0.2380
# Epoch 47/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2853 - val_loss: 0.2359
# Epoch 48/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2868 - val_loss: 0.2350
# Epoch 49/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2856 - val_loss: 0.2331
# Epoch 50/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2849 - val_loss: 0.2324
# Epoch 51/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2872 - val_loss: 0.2320
# Epoch 52/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2889 - val_loss: 0.2306
# Epoch 53/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2876 - val_loss: 0.2307
# Epoch 54/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2840 - val_loss: 0.2302
# Epoch 55/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2839 - val_loss: 0.2285
# Epoch 56/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2827 - val_loss: 0.2271
# Epoch 57/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2882 - val_loss: 0.2286
# Epoch 58/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2881 - val_loss: 0.2277
# Epoch 59/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2823 - val_loss: 0.2269
# Epoch 60/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2893 - val_loss: 0.2273
# Epoch 61/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2816 - val_loss: 0.2254
# Epoch 62/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2875 - val_loss: 0.2253
# Epoch 63/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2832 - val_loss: 0.2249
# Epoch 64/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2854 - val_loss: 0.2243
# Epoch 65/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2887 - val_loss: 0.2255
# Epoch 66/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2834 - val_loss: 0.2250
# Epoch 67/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2845 - val_loss: 0.2250
# Epoch 68/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2867 - val_loss: 0.2259
# Epoch 69/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2870 - val_loss: 0.2263
# Epoch 70/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2807 - val_loss: 0.2242
# Epoch 71/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2786 - val_loss: 0.2229
# Epoch 72/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2784 - val_loss: 0.2219
# Epoch 73/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2893 - val_loss: 0.2236
# Epoch 74/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2825 - val_loss: 0.2216
# Epoch 75/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2805 - val_loss: 0.2210
# Epoch 76/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2836 - val_loss: 0.2217
# Epoch 77/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2802 - val_loss: 0.2216
# Epoch 78/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2862 - val_loss: 0.2221
# Epoch 79/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2832 - val_loss: 0.2225
# Epoch 80/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2816 - val_loss: 0.2226
# Epoch 81/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2820 - val_loss: 0.2218
# Epoch 82/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2800 - val_loss: 0.2223
# Epoch 83/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2827 - val_loss: 0.2216
# Epoch 84/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2794 - val_loss: 0.2211
# Epoch 85/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2814 - val_loss: 0.2211
# Epoch 86/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2802 - val_loss: 0.2220
# Epoch 87/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2790 - val_loss: 0.2201
# Epoch 88/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2830 - val_loss: 0.2207
# Epoch 89/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2821 - val_loss: 0.2204
# Epoch 90/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2771 - val_loss: 0.2195
# Epoch 91/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2804 - val_loss: 0.2190
# Epoch 92/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2868 - val_loss: 0.2207
# Epoch 93/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2834 - val_loss: 0.2205
# Epoch 94/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2841 - val_loss: 0.2203
# Epoch 95/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2861 - val_loss: 0.2208
# Epoch 96/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2834 - val_loss: 0.2209
# Epoch 97/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2849 - val_loss: 0.2217
# Epoch 98/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2854 - val_loss: 0.2209
# Epoch 99/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2770 - val_loss: 0.2199
# Epoch 100/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2750 - val_loss: 0.2191
# Epoch 101/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2787 - val_loss: 0.2190
# Epoch 102/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2854 - val_loss: 0.2214
# Epoch 103/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2812 - val_loss: 0.2199
# Epoch 104/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2833 - val_loss: 0.2193
# Epoch 105/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2841 - val_loss: 0.2205
# Epoch 106/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2850 - val_loss: 0.2211
# Epoch 107/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2842 - val_loss: 0.2210
# Epoch 108/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2851 - val_loss: 0.2213
# Epoch 109/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2892 - val_loss: 0.2225
# Epoch 110/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2843 - val_loss: 0.2223
# Epoch 111/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2822 - val_loss: 0.2210
# Epoch 112/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2801 - val_loss: 0.2200
# Epoch 113/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2915 - val_loss: 0.2230
# Epoch 114/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2844 - val_loss: 0.2226
# Epoch 115/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2846 - val_loss: 0.2219
# Epoch 116/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2809 - val_loss: 0.2217
# Epoch 117/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2814 - val_loss: 0.2200
# Epoch 118/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2764 - val_loss: 0.2185
# Epoch 119/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2855 - val_loss: 0.2192
# Epoch 120/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2892 - val_loss: 0.2213
# Epoch 121/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2812 - val_loss: 0.2206
# Epoch 122/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2874 - val_loss: 0.2213
# Epoch 123/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2788 - val_loss: 0.2210
# Epoch 124/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2842 - val_loss: 0.2209
# Epoch 125/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2829 - val_loss: 0.2203
# Epoch 126/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2844 - val_loss: 0.2207
# Epoch 127/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2851 - val_loss: 0.2215
# Epoch 128/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2802 - val_loss: 0.2204
# Epoch 129/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2851 - val_loss: 0.2208
# Epoch 130/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2846 - val_loss: 0.2213
# Epoch 131/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2783 - val_loss: 0.2198
# Epoch 132/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2710 - val_loss: 0.2177
# Epoch 133/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2868 - val_loss: 0.2189
# Epoch 134/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2782 - val_loss: 0.2186
# Epoch 135/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2799 - val_loss: 0.2187
# Epoch 136/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2774 - val_loss: 0.2179
# Epoch 137/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2844 - val_loss: 0.2194
# Epoch 138/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2861 - val_loss: 0.2196
# Epoch 139/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2812 - val_loss: 0.2195
# Epoch 140/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2840 - val_loss: 0.2193
# Epoch 141/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2795 - val_loss: 0.2186
# Epoch 142/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2840 - val_loss: 0.2193
# Epoch 143/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2792 - val_loss: 0.2189
# Epoch 144/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2788 - val_loss: 0.2185
# Epoch 145/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2800 - val_loss: 0.2186
# Epoch 146/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2817 - val_loss: 0.2180
# Epoch 147/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2756 - val_loss: 0.2172
# Epoch 148/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2759 - val_loss: 0.2159
# Epoch 149/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2809 - val_loss: 0.2165
# Epoch 150/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2855 - val_loss: 0.2183
# Epoch 151/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2805 - val_loss: 0.2189
# Epoch 152/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2834 - val_loss: 0.2185
# Epoch 153/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2815 - val_loss: 0.2188
# Epoch 154/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2831 - val_loss: 0.2197
# Epoch 155/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2780 - val_loss: 0.2187
# Epoch 156/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2777 - val_loss: 0.2175
# Epoch 157/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2838 - val_loss: 0.2202
# Epoch 158/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2763 - val_loss: 0.2181
# Epoch 159/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2784 - val_loss: 0.2181
# Epoch 160/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2783 - val_loss: 0.2169
# Epoch 161/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2851 - val_loss: 0.2185
# Epoch 162/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2773 - val_loss: 0.2175
# Epoch 163/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2821 - val_loss: 0.2183
# Epoch 164/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2831 - val_loss: 0.2192
# Epoch 165/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2860 - val_loss: 0.2192
# Epoch 166/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2804 - val_loss: 0.2193
# Epoch 167/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2835 - val_loss: 0.2203
# Epoch 168/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2835 - val_loss: 0.2194
# Epoch 169/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2789 - val_loss: 0.2184
# Epoch 170/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2758 - val_loss: 0.2176
# Epoch 171/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2789 - val_loss: 0.2172
# Epoch 172/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2797 - val_loss: 0.2187
# Epoch 173/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2830 - val_loss: 0.2187
# Epoch 00173: early stopping

# %%
losses=pd.DataFrame(model2.history.history)
losses.plot()

# %%
predictions=model2.predict_classes(X2_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[   0  202]
#  [   0 1283]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       202
#            1       0.86      1.00      0.93      1283
#
#     accuracy                           0.86      1485
#    macro avg       0.43      0.50      0.46      1485
# weighted avg       0.75      0.86      0.80      1485
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model3.fit(x=X3_train, y=y_train, epochs=2000, validation_data=(X3_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.6638 - val_loss: 0.6186
# Epoch 2/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.5776 - val_loss: 0.5241
# Epoch 3/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.4772 - val_loss: 0.3961
# Epoch 4/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3880 - val_loss: 0.3531
# Epoch 5/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3726 - val_loss: 0.3456
# Epoch 6/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3664 - val_loss: 0.3375
# Epoch 7/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3552 - val_loss: 0.3295
# Epoch 8/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3473 - val_loss: 0.3221
# Epoch 9/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3400 - val_loss: 0.3142
# Epoch 10/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3334 - val_loss: 0.3071
# Epoch 11/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.3255 - val_loss: 0.2979
# Epoch 12/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3165 - val_loss: 0.2912
# Epoch 13/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3132 - val_loss: 0.2852
# Epoch 14/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3088 - val_loss: 0.2782
# Epoch 15/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.3029 - val_loss: 0.2725
# Epoch 16/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2967 - val_loss: 0.2661
# Epoch 17/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2920 - val_loss: 0.2602
# Epoch 18/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2879 - val_loss: 0.2543
# Epoch 19/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2801 - val_loss: 0.2484
# Epoch 20/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2817 - val_loss: 0.2438
# Epoch 21/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2747 - val_loss: 0.2392
# Epoch 22/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2758 - val_loss: 0.2344
# Epoch 23/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2720 - val_loss: 0.2307
# Epoch 24/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2665 - val_loss: 0.2272
# Epoch 25/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2662 - val_loss: 0.2234
# Epoch 26/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2625 - val_loss: 0.2196
# Epoch 27/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2620 - val_loss: 0.2175
# Epoch 28/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2568 - val_loss: 0.2151
# Epoch 29/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2596 - val_loss: 0.2124
# Epoch 30/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2573 - val_loss: 0.2131
# Epoch 31/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2572 - val_loss: 0.2092
# Epoch 32/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2558 - val_loss: 0.2077
# Epoch 33/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2495 - val_loss: 0.2048
# Epoch 34/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2510 - val_loss: 0.2036
# Epoch 35/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2514 - val_loss: 0.2032
# Epoch 36/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2503 - val_loss: 0.2014
# Epoch 37/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2573 - val_loss: 0.2042
# Epoch 38/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2505 - val_loss: 0.2005
# Epoch 39/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2505 - val_loss: 0.1998
# Epoch 40/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2470 - val_loss: 0.1977
# Epoch 41/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2464 - val_loss: 0.1976
# Epoch 42/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2476 - val_loss: 0.1968
# Epoch 43/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2507 - val_loss: 0.1970
# Epoch 44/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2449 - val_loss: 0.1971
# Epoch 45/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2431 - val_loss: 0.1965
# Epoch 46/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2490 - val_loss: 0.1954
# Epoch 47/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2482 - val_loss: 0.1963
# Epoch 48/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2483 - val_loss: 0.1959
# Epoch 49/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2482 - val_loss: 0.1957
# Epoch 50/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2432 - val_loss: 0.1941
# Epoch 51/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2405 - val_loss: 0.1943
# Epoch 52/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2469 - val_loss: 0.1934
# Epoch 53/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2475 - val_loss: 0.1953
# Epoch 54/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2467 - val_loss: 0.1941
# Epoch 55/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2401 - val_loss: 0.1931
# Epoch 56/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2468 - val_loss: 0.1945
# Epoch 57/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2449 - val_loss: 0.1937
# Epoch 58/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2539 - val_loss: 0.1961
# Epoch 59/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2525 - val_loss: 0.1951
# Epoch 60/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2474 - val_loss: 0.1944
# Epoch 61/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2486 - val_loss: 0.1945
# Epoch 62/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2412 - val_loss: 0.1928
# Epoch 63/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2392 - val_loss: 0.1926
# Epoch 64/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2398 - val_loss: 0.1927
# Epoch 65/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2406 - val_loss: 0.1939
# Epoch 66/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2396 - val_loss: 0.1922
# Epoch 67/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2339 - val_loss: 0.1907
# Epoch 68/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2405 - val_loss: 0.1903
# Epoch 69/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2450 - val_loss: 0.1920
# Epoch 70/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2467 - val_loss: 0.1921
# Epoch 71/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2434 - val_loss: 0.1920
# Epoch 72/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2392 - val_loss: 0.1908
# Epoch 73/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2481 - val_loss: 0.1919
# Epoch 74/2000
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2500 - val_loss: 0.1927
# Epoch 75/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2469 - val_loss: 0.1931
# Epoch 76/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2389 - val_loss: 0.1928
# Epoch 77/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2432 - val_loss: 0.1935
# Epoch 78/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2395 - val_loss: 0.1929
# Epoch 79/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2449 - val_loss: 0.1940
# Epoch 80/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2458 - val_loss: 0.1928
# Epoch 81/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2393 - val_loss: 0.1924
# Epoch 82/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2427 - val_loss: 0.1924
# Epoch 83/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2381 - val_loss: 0.1920
# Epoch 84/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2424 - val_loss: 0.1913
# Epoch 85/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2442 - val_loss: 0.1932
# Epoch 86/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2461 - val_loss: 0.1929
# Epoch 87/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2395 - val_loss: 0.1914
# Epoch 88/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2409 - val_loss: 0.1916
# Epoch 89/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2473 - val_loss: 0.1931
# Epoch 90/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2353 - val_loss: 0.1912
# Epoch 91/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2357 - val_loss: 0.1904
# Epoch 92/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2471 - val_loss: 0.1928
# Epoch 93/2000
# 109/109 [==============================] - 0s 1ms/step - loss: 0.2386 - val_loss: 0.1919
# Epoch 00093: early stopping

# %%
losses=pd.DataFrame(model3.history.history)
losses.plot()

# %%
predictions=model3.predict_classes(X3_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[   0  202]
#  [   0 1283]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       202
#            1       0.86      1.00      0.93      1283
#
#     accuracy                           0.86      1485
#    macro avg       0.43      0.50      0.46      1485
# weighted avg       0.75      0.86      0.80      1485
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # We have sucessfully developed models for the prediction of the student performance, but how can we choose one?
#
# * First of all, the models in which both *weighted_grade* and *pass_rate* were included overall performed better than their omitted counterparts, suggesting that our hypotheses was wrong
#
# * The neural network classifiers had difficulties predicting the cases of failure, but overall had a better performance tha the other models, probably due to the removal of one class.
#
# * The other models could be used in headhunting programs, developed to select students who are very likely to graduate with distinction and offering them scholarships, jobs, etc.
#
# * Altough I created a lot of features I wonder how many other features could be created for this problem and how would they improve model performance. If you are curious too, fork this notebook and give it a try too!
#
# Thanks for reading my kernel and keep learning!
